# %% [markdown]
# # Case Study 3
#
# Build a spam classifier using naive Bayes and clustering. You will have to create your own dataset from the input messages. Be sure to document how you created your dataset.

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from collections import Counter
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import os
import re
import email
from html.parser import HTMLParser
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import SnowballStemmer
import pandas as pd
import string
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.sparse import csr_matrix
import scipy
# %matplotlib inline

# %%
easyham=[]
targets_easyham=[]
easy_ham = os.listdir('./SpamAssassinMessages/easy_ham/')
for i in easy_ham:
    with open(os.path.join('./SpamAssassinMessages/easy_ham/',i), 'r') as f:
        try:
            x = email.message_from_file(f)
        except:
            print(f'msg {i} not read')
    mailType = x.get_content_type()
    textType = x.get_content_charset()
    if mailType == 'text/plain':
        easyham.append(x.get_payload())
        targets_easyham.append(0)
    elif mailType == 'text/html':
        tmp = BeautifulSoup(x.get_payload(), 'html.parser')
        tmp = tmp.text.replace('\n', ' ')
        easyham.append(tmp)
        targets_easyham.append(0)
    elif x.is_multipart():
         for j in x.walk():
            mailType = j.get_content_type()
            textType = j.get_content_charset()
            if mailType == "text/plain":
                easyham.append(j.get_payload())
                targets_easyham.append(0)
            elif mailType == "text/html":
                tmp = BeautifulSoup(j.get_payload(), 'html.parser')
                tmp = tmp.text.replace("\n"," ")
                easyham.append(tmp)
                targets_easyham.append(0)
    else:
        print(f'msg {i} not parsed')
        print(x.get_content_type())
        print(textType)
# Out:
# msg 0461.7609029b07acf65f40bd93882aa35887 not read
# msg 0146.2d301a1e07672538d669f5e571180d32 not read
# msg 02293.2ae2c667486323afb16d109b406b8783 not read
# msg 01270.49d052edd258d0f9eb08ca05e177f965 not read
# msg 01254.e1ba700d620871e67b4f7db4b8859ac3 not read
# msg 0289.cb9c0595bddae2c25357ce5c9fbaf687 not read
# msg 0225.80a615200726ed2da1bfd347dcfd648c not read
# msg 01247.2a40443c1cba2e07a993b186db41971d not read
# msg 2538.e3f596927fd5dd74ad23a0792a449241 not read
# msg 01042.5379f7151fef6cce3e2638aee3b193fa not read
# msg 0287.18f9a821d67a503c0d54a2356a0f8a4a not read
# msg 0178.8405bbe39a5eb6c1814e3c16602099a4 not read
# msg 00215.d09b3f3c0df56258c17c3de4dfbfc6c6 not read
# msg 2445.631e9fa95e78d7f56fce09a4e6da56fd not read
# msg 01217.ca4f6cab0653e40829f209aefb242ae0 not read
# msg 1013.8355d120301841c6b601bee02bb4c14f not read
# msg 1429.3c60313af6a2a5c79bb97e06855a4af7 not read
# msg 0521.56b24a33e65cd045de37e6bec5ec30e3 not read
# msg 00114.240461056916c0cdd555ba9d2bc9e63e not read
# msg 0300.2e30b3bffb4f2887df203c197d11e936 not read
# msg 00247.e14fcbf137267399278507b469811f0a not read
# msg 00581.9922b0f34aa8f51fb4adf4bf4ecf1464 not read
# msg 01543.044ee0da6eaa44adbadc131be0bcb2d2 not read
# msg 0268.77ef28e27a9ee085646f260418072111 not read
# msg 1119.ce22f4a2ffbc03cd2625cb10ba561058 not read
# msg 00745.d2df6fc9d5de220dc9b34cf04addf9e2 not read
# msg 00023.e0e815ea1d7fd40e7e70b4c0035bef0c not read
# msg 01360.542f5bf8fe1935cc079504c0a0269923 not read
# msg 00713.7b4a3ad6c8b6bbcf358ee5ee23dcdc12 not read
# msg 2324.65b1fb56947693e7618b40f57c49c61b not read
# msg 0196.0e960d0db312a26fade743e699ac5428 not read
# msg 00165.a626a87fa5b56f724e6a00e7c1ec163a not read
# msg 00595.7182665eb052808e2061bacbc75ed5ee not read
# msg 00368.f86324a03e7ae7070cc40f302385f5d3 not read
# msg 00413.e637d3bed73c6df691dc86dd61d46192 not read
# msg 0027.11da06d9130a188bf0ffb2060881dbe9 not read
# msg 1649.00d75963b0db438a7f492b59a5395fc0 not read
# msg 00738.5c6ce770da4cc06ebea777b8be30abaa not read
# msg 02445.c8fd8c92ab5a91bbf5e94e5277a47863 not read
# msg 00166.8feace9f17d092d9532e62c35c37ce95 not read
# msg 1022.73ab70b91862d709897cfe3dd5bb22a0 not read
# msg 0326.703aa5be82f6586d348723b732176418 not read
# msg 01295.c440ea598ea18fee4cf3d2a1a9cd6864 not read
# msg 00236.0d42e8e99de86aae42a4f3e3cdc2465b not read
# msg 01557.25496d0c7fc8acbf284debadd4f1dc07 not read
# msg 0550.8e86f9859287ac9846e3c179b29e0fc1 not read
# msg 0203.5f055220d95eaa1de71c7f24e004a7f5 not read
# msg 2384.835c56e56932e88a89271d2d13df9a8c not read
# msg 02472.5c879dd55c3d4171e1787e8529bbd7e1 not read
# msg 1131.7f31a18433046205b44e6b46f9677f9a not read
# msg 02488.68fed64ff8169f1505b74080bb7b6158 not read
# msg 01039.2b799ff9acbf233a7842eab00fcb848f not read
# msg 02189.87c2e44a35ec0e62b20783d9a29d5c5e not read
# msg 2109.094078fcb88b4e1fa5eb9fc67ba998bc not read
# msg 00342.e6c781df2ebba44a429b49b86b376559 not read
# msg 00733.8cd99b24ae020e6028d85ad0c4f06186 not read
# msg 1365.83f365382e725776956f137a4600117e not read
# msg 01549.a465f982502ac6d7c10118f1939f6974 not read
# msg 01291.dfc4b8ceb611c971fb6b821eecaa9cea not read
# msg 01084.f085d737f5244ffe14e8743e9226fd30 not read
# msg 01034.6a298abdc5efe614a638c2b55582cdc6 not read
# msg 00220.7c18420ed3257e8630e67dd0045f6563 not read
# msg 00180.1d7edb742cfbd5d48881c99a8e03cccd not read
# msg 2429.ba3172b8bb1849e4ef208584b4fa51dd not read
# msg 00796.1c06b1656c17f8aa92a42a82ef0ad2e9 not read
# msg 00942.727cb1619115cdee240fa418da19dd1f not read
# msg 00163.550a6ef7fd451fba494cc3128aaf3c7c not read
# msg 00302.9aa28800eefcb167ac80f4b6b1e939d6 not read
# msg 00057.7c3a836baaa732cd915546442c0fef1a not read
# msg 02274.d25fe5d3adc798112cd281bd89d642db not read
# msg 1162.0ac7999a1814c6e79d6da0f6fb8ec301 not read
# msg 02447.5ecaa423bfa4ab050e5b9a0a34f6191f not read
# msg 02483.ab1bee02c10ddecc0e86c39eaebc2996 not read
# msg 0238.7b9b9b2e3b3ca24ae8960f03aab57964 not read
# msg 0551.5bdfb0c299c60e442e39346dc08bad68 not read
# msg 1303.b8fb03a2de8615f9287086ccc71a4282 not read
# msg 0347.0e43f8ba3aadeed419f512188e5d8aa4 not read
# msg 1238.af17c6dc01076c3f5fd80b0aaf13b70a not read
# msg 02140.ccabcb71ece6c0835518e4c7900ef94b not read
# msg 0357.1dbdc4d7a9e7e290455af62c1df78649 not read
# msg 00532.81180d4d1d632bb50c189b51f83921e0 not read
# msg 0794.cf41a55933ae8896b668864d7b57b177 not read
# msg 2396.8126a8ee1ebb7fe484a5709f96192b02 not read
# msg 0806.2eae7f9f133274ed400a215174b7de1d not read
# msg 0808.426e30e31a3d3fab634e31e8aeb30c34 not read
# msg 0282.fd87e7b9765004f6123ebe981bc16a1c not read
# msg 2132.559afb271ce8b31e8e3a0c32e668cbbe not read
# msg 1653.19b45239333519205611b669843294cd not read
# msg 1121.51f7e5e557bde451a6b36e527211ed04 not read
# msg 0799.eb9fe164fe9541253b4ab806626ab171 not read
# msg 01156.64602d74854cb26859c88c6f560fca27 not read
# msg 01236.80295013ea9517181a3a42ad0d4a7f63 not read
# msg 01554.0aed12846b3981a2a13adf793083e4f0 not read
# msg 00644.47e9eaa5c1cac5f991f30201ae7fda6e not read
# msg 0656.dd2af7ab5d99adf717056893adb12a20 not read
# msg 02323.dbe22daff2cf3e9c7aa284ec961481c4 not read
# msg 0381.040644bb43a533c43f40361bd1d35355 not read
# msg 02333.2a59c82074b44c35e79462984c8f8d9d not read
# msg 00007.37a8af848caae585af4fe35779656d55 not read
# msg 0549.59f3057eef31f2b8ebb02446556a3f37 not read
# msg 00009.371eca25b0169ce5cb4f71d3e07b9e2d not read
# msg 1340.763507dad3b921f972640d4d76172f7e not read
# msg 01111.2f7361f87bcf1782c2f7622d92c6bf7d not read
# msg 00936.e8fd8c240b680e948f85f2326cc87250 not read
# msg 02339.6a217c7473a881cc0d68a2c1617722e4 not read
# msg 02354.3be731874b373f98e66b3254f75a30b6 not read
# msg 1360.18758d232e8b6937d5d62ce0e0aa2d8e not read
# msg 00570.d98ca90ac201b5d881f2397c95838eb2 not read
# msg 0239.58f51c99b02fc8b49664f15a855af780 not read
# msg 00492.3ffb38f175e41790b1f05096dbe339d8 not read
# msg 1285.b9998969053e427bd4c4c0c6e68518ec not read
# msg 0402.a511fb74deca95f59d4eff5daa45a9b8 not read
# msg 00554.a01a74aee9653a7ae8d1d558c75f0a5d not read
# msg 00931.c27bf5c9bcb24c213aafe1b28fcbcc7a not read
# msg 00439.982a2ff6189badfe70c2fe3c972466a2 not read
# msg 00591.3bca4fff29ae5e89e2e2948401a24ab8 not read
# msg 01556.126fd032d9f624e282a711df96f64cc6 not read
# msg 2380.106606551f4a5c1e0065eeb0f3a331a2 not read
# msg 2399.8815bb6c714226c9a83ad8d743d7688d not read
# msg 00218.17547ce08d682678c539484cf094982d not read
# msg 0495.5c4fb5aab57f610e00c4d3b951216f16 not read
# msg 00493.29a23aaa27a825c8cfb67264b9d7aeb3 not read
# msg 02290.63a40c780fe1f8e771f62473dc3dce0b not read
# msg 1164.4f5726c74bd69e322849d54f54a646fe not read
# msg 1116.e30f22bbdea56cb1ba244a559564ddde not read
# msg 1378.12eda7069e9d8a08ba37f0e4679f23ea not read
# msg 0267.218a528c448166d39f853cf75d8890dd not read
# msg 02278.5681f9fd02e38391b917d4623ff9d198 not read
# msg 01199.59f410d0b6c37510d6a29d0d02f62101 not read
# msg 1184.152999961bd0606fb0dcb6d6f95cc96d not read
# msg 00161.e75ee4467e41dd1d5f5156f2b9ca5bd8 not read
# msg 00558.95b8c2677759a2f569a5dc0bd70b8cc0 not read
# msg 00747.39967f26d6c1cba3713e2b9f318d0531 not read
# msg 0857.c5290c6dee60d45314e519678e96735c not read
# msg 0589.8646984ed76a8df2811750d151f56b1e not read
# msg 0080.7c3a836baaa732cd915546442c0fef1a not read
# msg 2460.8a782dd603bfe327c2f7adadf590a094 not read
# msg 1333.e9f5229e15c55a75e02a92fe42324bce not read
# msg 02236.46b510d2f030ddaa7bcc52ef26535bae not read
# msg 1309.a63c188095d5f70604ec9c3a5f96ce0e not read
# msg 0640.95f677f7c53a182c30e068eaab74950e not read
# msg 01102.d178bf64121423fea27fcbf754d5f984 not read
# msg 01550.a036d340bdcf122c8eca891557d50b51 not read
# msg 0552.1ce63d212148c58723cc1f7150b27157 not read
# msg 1716.fabf67851c347abee56594b9873b2d9a not read
# msg 02087.1d6e87f2e6e97b044d7c4955a1e394a1 not read
# msg 01337.e515b1d01d6d98606d994b1c8901904c not read
# msg 00405.c838c0717624d85d5a53371fdbce5955 not read
# msg 01274.bfe4843cd130926efe53dc96bd3dfeea not read
# msg 00765.ea01c46568902b1338c9685b55d77f6c not read
# msg 00119.0f469afee6aef0a05d9850f7021bd629 not read
# msg 0151.4d1c8772327e44b20af6420e1d1c0a75 not read
# msg 2342.f3a2998bb86db89f22971aceca333a98 not read
# msg 0773.e1edafa86a1670e9515d4d9c1bb288c9 not read
# msg 00469.b1d31cab7c1b3b5897393f46ce62b3e9 not read
# msg 00935.8ecbeab3ef30caba2c29e25744a2265a not read
# msg 1383.4e6c2c19a9c9ff985a966f06ea87ed76 not read
# msg 00494.ba6ae1d625f2a4e039f6822868ee48ad not read
# msg 1014.8262a256b8f2e481dcae966b0c5088e8 not read
# msg 0297.738b9e94deb4bf077221292f071de345 not read
# msg 0652.5ed46908836bacba742b337197ce3499 not read
# msg 02026.e6e094c6110cbff0c3a55e0fc5c9273a not read
# msg 0208.0577aa26cbb2382d8789377d351ca8bf not read
# msg 00734.e37922bdfd9e3246c18322e4b07a4b23 not read
# msg 01268.0cd2c295a12fb03140c6549cb8980012 not read
# msg 0321.b100345ae7b5e980f41d9c6e0ff3159a not read
# msg 0611.4a47b06e83edee6c61ba37d1be2a09d0 not read
# msg 01794.e322c3e66406d3a985a61aba25902c5b not read
# msg 00244.d6a35c3356b3796b5ddc77ed1b1995e2 not read
# msg 0615.935b5a30e35ec46502a33a445443c124 not read
# msg 1502.1376704c3bd9c110fe3a5d0768745d91 not read
# msg 02048.146a986ae719349d6b6e4d5f9c0e38bd not read
# msg 2295.e84ec70f3e8ec47c77536f28d5b9c92d not read
# msg 00495.3bba63110f3a2a97ae71ce53268766cf not read
# msg 02218.f615f1b7360b9a22a0c9387f285a5af0 not read
# msg 00234.335356ba4b116d347be3199b40cdaed2 not read
# msg 0469.8b40f778677e8d001ca14bcc4268b41b not read
# msg 02301.a12a68c684b8c32e4f93cf6628e9eb5c not read
# msg 2483.9eb471e8645403dda2bd70c08b463faf not read
# msg 00347.f133df7e59af41ba1c596e60dde9dc48 not read
# msg 00271.b67b5b37ce874d5ccea3391922f14506 not read
# msg 0269.5a74b38284c7e9d85338eca0a25cb191 not read
# msg 0423.353c3de8f5c7114179771f9b44e70b9e not read
# msg 2154.0949f10e9c0050803f5e324f72641e80 not read
# msg 02320.9d983e803c0325063c06097d7bb4b3f1 not read
# msg 1124.ca18e9fe0618bbac33ef2156d047cc7d not read
# msg 0205.84f75723dcf7639ed057a32283048bdf not read
# msg 02067.4d2f2b0ae64c68570f08423ed43ce845 not read
# msg 01615.63a41aa663eeaf93728e7b1ab572ce91 not read
# msg 1656.2c519e6e148cca3020e50c723bbc200e not read
# msg 1010.1bc4545387a6a526b351a330b4aca16c not read
# msg 00934.f9ba910a655535304bf26a3e281cb324 not read
# msg 00614.2487f80400eb954b7c3ab257771ed393 not read
# msg 1015.f399ba43c22e3fdb1a22261714062cbd not read
# msg 00219.642f44312e1eaf0fbecf90d6b39876d9 not read
# msg 2439.c8c3aa25791710ac30aaaa49cb276f12 not read
# msg 1354.0cbd2821c28f742dfdcf33ffbfaeebac not read
# msg 0638.70122b70a334560fdbc450b6516bf752 not read
# msg 2451.1ccaf9bc09a2b8e339f02d21ac62f437 not read
# msg 2193.8220cdccae38ad8e4984999416bc3c92 not read
# msg 0891.44f5cad6f0dfa66277e1a0aec55e7bf6 not read
# msg 00534.6db349fcd98d25f61e5bcc4552b45f57 not read
# msg 02419.ade095af23802012668f4ec856bf7e63 not read
# msg 01049.91539978b8a1bbef1b7eef0bb123b07c not read
# msg 0795.6f8b4da0f06a9c055fc527562fe92330 not read
# msg 1897.91a261359b5537a465fa0164ec1d95c6 not read
# msg 1322.7faaa22a10e2eab022719a868f587686 not read
# msg 1452.81f3e3d1b40f978cd3c0125e7020dd17 not read
# msg 0591.f533bea095d75cc4dc282bdcba69072a not read
# msg 0648.35cbc1bb7547966c1171f83d2312d4a9 not read
# msg 00160.eb0db8e14a3308c08db1cc38c4c7d66a not read
# msg 01035.1210cd8593aa0ed6eb21b86b9c97cc46 not read
# msg 00266.edda19cbe2bb12d6aca8f9550b870824 not read
# msg 1356.14e3ab9f37daa13ce7a15770017c4863 not read
# msg 2173.23722932b26a06491eec963ae3531df5 not read
# msg 02469.901d2dc268a72e42497dac1ea80d861d not read
# msg 1444.9c769de9af58bfba4b3e6b0ca034f2b8 not read
# msg 00229.5ee5fd3867d69cd25a5fde771fda0094 not read
# msg 00583.7db5166f3ec5a8bcf81bf1b639b48361 not read
# msg 0320.6c54ea1bb991c6fae395588219cfce37 not read
# msg 0240.01e0e10c03592e64df9a077f2cd56aba not read
# msg 0826.082e92a79a15aa7f6dd5b85a40327abd not read
# msg 00155.22281cddbc29a93d630798e0aa97f725 not read
# msg 01280.08e69f637d901fab10aec6c9492d068e not read
# msg 00183.54d98788fca5892267d8dfe4d09b2bbf not read
# msg 02287.05088931220174dcef44fd30efb3616d not read
# msg 00265.d0ebd6ba8f3e2b8d71e9cdaa2ec6fd91 not read
# msg 1163.3ad31ba9c55ae030d3d708b5987f889e not read
# msg 0010.4996141de3f21e858c22f88231a9f463 not read
# msg 00599.94c013ab7037d45045aafbac3389bef0 not read
# msg 00402.8e937401f8a8a7a1c7661e076f96cd55 not read
# msg 0222.160c5b2e2a80f71367b4d9a47f8f9d4e not read
# msg 1166.8a9dbee6ac67226f58a80c0993a700e2 not read
# msg 2419.104f029a2c2f3ddb0c756e7dd26501da not read
# msg 0228.b83f2f4ef114c69d9ca927d1082b393f not read
# msg 1398.02fd0caad73d10ee02aebd13b761f135 not read
# msg 01307.4b06bdd9604366d63b4106aa8c715c06 not read
# msg 1193.8805a7218e81db9893ee2b704d9ebeb1 not read
# msg 0008.20bc0b4ba2d99aae1c7098069f611a9b not read
# msg 00186.7fb6108d51b6cf37e682b16713376f98 not read
# msg 01081.844461cf79fe409cdfed1c9456c064f0 not read
# msg 01409.6874e3b9aad08eb5081dfcbaa3871ffe not read
# msg 0207.f7d2d40df256d6caea05314f5334a959 not read
# msg 02433.9cfb47708291604f2c38393706175160 not read
# msg 0673.1850e124a4ef3beb85071e67d7f8bf6d not read
# msg 0397.bdea17c7f90068a763d191914770f6d6 not read
# msg 01082.39917c590e0204c5de0142acd3fb3d08 not read
# msg 0202.e1c7980f6c8a70122d80771533795cb7 not read
# msg 1648.feab1eecf41d21e438b3658a5ab15f80 not read
# msg 01279.8cd7c5fcfd7a06b4e2b066a7c76846fe not read
# msg 2246.b66caa903ee41f0f8d81281f1ab1bd8e not read
# msg 00914.a24840d53c5f49a00e66fa4425e4626d not read
# msg 00830.3a2cadbd29e654a7cbbf64ba4bdc378d not read
# msg 00464.5a7f552394a07524c4aa23b06c9e5915 not read
# msg 0627.c9ad8730dad7bda1e1169ee00c4006fc not read
# msg 02340.de68a83f900418f6cde87bdf92801f73 not read
# msg 1655.7a0d7700a207ef6f66686f94b02c7a8f not read
# msg 0264.a1183a59e4f0a71e80378d9404a3212f not read
# msg 2393.9ba2bbda6af818512632047ddd5aea4a not read
# msg 00326.e77a07ed3bc9f0e54bc12c3ea32e25fa not read
# msg 0526.615f918b4860d437577f6aa66c9b37cf not read
# msg 01080.b8d12c010e45434e95f67889e26ba456 not read
# msg 2426.ba29d4b97bc1e42b7b12f678cf41d981 not read
# msg 0457.dc1691cbb334cc33a1f1eb3060b8e02e not read
# msg 02003.0efdf5386d93ddbff346b304c637ab35 not read
# msg 0226.aafb7854f8f17e90f7e5e5f99c54e76e not read
# msg 2407.c9318bb61b808a141780fa5067d53a05 not read
# msg 0977.d0e3f4e7fd0a8c2bdd26888af1ca3a0b not read
# msg 02345.52eedf6f431a61908c62a4d561e655fe not read
# msg 2446.34e896282d23f593971bf47f5bb1ab0b not read
# msg 1642.c4eea2387cc6850b5e1cb84529535f8b not read
# msg 01352.400cef8d0d007f3d7ba8a0c7a8717fcb not read
# msg 1117.571c1399a9b49bf25062fcd2242d72f1 not read
# msg 02313.792888aeb3a4fdd1adcbbb094959714c not read
# msg 0704.f62f0ee295a7f648249c8104a8e45843 not read
# msg 0156.3d3293a5da919cf65959e6bd63feaf27 not read
# msg 0235.3c824d680d31b3710d8f3475730dc42d not read
# msg 00184.4534b61b19d6102fe241eecf0a436a35 not read
# msg 1366.200cc41f250f28147c5db07ea933f26a not read
# msg 00292.d70b6d753352d01060579b1c34df4e4d not read
# msg 01223.bd57469f0b8c0ca986d7a3f40681b56e not read
# msg 02372.ba6a7288c11b60bd92e3245c76652846 not read
# msg 01037.6b42b5f3d3d9e6293bf24af66b250655 not read

# %%
easyham2=[]
targets_easyham2=[]
easy_ham2 = os.listdir('./SpamAssassinMessages/easy_ham_2/')
for i in easy_ham2:
    with open(os.path.join('./SpamAssassinMessages/easy_ham_2/',i), 'r') as f:
        try:
            x = email.message_from_file(f)
        except:
            print(f'msg {i} not read')
    mailType = x.get_content_type()
    textType = x.get_content_charset()
    if mailType == 'text/plain':
        easyham2.append(x.get_payload())
        targets_easyham2.append(0)
    elif mailType == 'text/html':
        tmp = BeautifulSoup(x.get_payload(), 'html.parser')
        tmp = tmp.text.replace('\n', ' ')
        easyham2.append(tmp)
        targets_easyham2.append(0)
    elif x.is_multipart():
         for j in x.walk():
            mailType = j.get_content_type()
            textType = j.get_content_charset()
            if mailType == "text/plain":
                easyham2.append(j.get_payload())
                targets_easyham2.append(0)
            elif mailType == "text/html":
                tmp = BeautifulSoup(j.get_payload(), 'html.parser')
                tmp = tmp.text.replace("\n"," ")
                easyham2.append(tmp)
                targets_easyham2.append(0)
    else:
        print(f'msg {i} not parsed')
        print(x.get_content_type())
        print(textType)
# Out:
# msg 01128.efb36914ecb55d78a894591eff0843c5 not read
# msg 01165.6ac614b3ccada8b003ad8586c8b88e4e not read
# msg 00990.3a91d53e9908fc65cf31a6c57e2a844d not read
# msg 00344.ff7eb63964aa85d7fc7cf9518b8bcdf1 not read
# msg 00288.9388b51e29a2d52191fcb2b053ace210 not read
# msg 00378.6634f5d52bac8536d979753841ade35a not read
# msg 00464.a528da6b60ce0122804319d1d3a9a708 not read
# msg 00554.ce77b9d5b74e0fa03b1d97d172dbfc4d not read
# msg 00354.98d3b7fe5983f71c36117b2aceb5dcd3 not read
# msg 01138.921e383bac77952cac8d28c91d603d15 not read
# msg 00209.3ebcc564b5a595d391416cba9d0696d0 not read
# msg 00959.a24f34fb3d342beaf6fc1df54b00e5a2 not read
# msg 00500.2c54eea1fb7f8bad057871a317212ad6 not read
# msg 01266.94f7e1cce0ec1935ca75d232e4dc684c not read
# msg 01143.a6289fefeaa0f9eeda2c0f2181651467 not read
# msg 00218.64c9d00b1056b230a115692edc35e85a not read
# msg 00101.a1cfb633388cd5afa26f517766c57966 not read
# msg 01190.dd6ead8cfbe0f8c5455841ed0e944488 not read
# msg 00270.a19a99f7377bfdd22784a5335fb78d70 not read
# msg 00014.8e21078a89bd9c57255d302f346551e8 not read
# msg 00350.e738a16c1483dfda97d5862b4a9a77f8 not read
# msg 00136.ad45de584fcb47c912a00b30e93c890b not read
# msg 01197.dc4ef655f103b591edd2b5f0956c414f not read
# msg 01232.8077cd29af0f1eb3a7c1b125375d9a9e not read
# msg 00051.c2215fd876c5f9e5da959c16c8e1b115 not read
# msg 01357.102c99f3c387520d97c19c884c886355 not read
# msg 00281.8166d0f6c6bd6eb4ab1a9730ffbdf383 not read
# msg 00102.f05fb87d2b36b53117cb8b5f645b9016 not read
# msg 00585.a9763d3908545b69df03e1f239af6f28 not read
# msg 01168.387e59c34fb395201b4002238b8009fd not read
# msg 00693.2183b91fb14b93bdfaab337b915c98bb not read
# msg 01179.1aeec6e94d2829c1dd756d3609a8eccf not read
# msg 01057.b2810601523d3bb9051088959078e309 not read
# msg 00028.4e9595edd918f1a5fa26f8740cfdb358 not read
# msg 00742.ce72d7c8245e881d6e0ee5d8e9cfabab not read
# msg 00166.8525e30f5b1574a4cb08d5fc8cb740e5 not read
# msg 00160.b7ad2878346c13c7726f872d632c42b5 not read
# msg 01173.0402e85910220618eac922403222d0ec not read
# msg 00169.701617763832617a7d0d1dfbc08b8a0d not read
# msg 00547.a4bff0b61d5617808712cf2085aa8170 not read
# msg 00631.3f9351806af9a88f93169ee3416e4502 not read
# msg 00278.f3d796448a64d0f66500884181458921 not read
# msg 00669.e1bd56f6a261852d752e086ae3f8f93d not read
# msg 00150.8f7dc1318823556f1eca402af39e08e5 not read
# msg 00552.bb5ababab06288f157e62ec89340d6c2 not read
# msg 00201.981524ec8ff1a3d171b662c1dbb831a7 not read
# msg 00361.ebcde1d624e84623713ac6eddff87943 not read
# msg 01169.5adc737d52bc101c6fd07732eeb5ed39 not read
# msg 00476.5248b39aaaf6f756eef865a6f43c1ff4 not read
# msg 00434.7a55a37b952e7fee5a292858697062c0 not read
# msg 00448.843eb6313e84a0bef7f1799405e2f1e9 not read
# msg 00445.4222549eadcf376d1f15942391cf806d not read
# msg 00665.087e07e6a5f47598db0629c21e6e1a70 not read
# msg 01140.67e11f7533ac73ebeb728c6fdb86eeff not read
# msg 01323.8f994027cca214b6e0e7df2d443ff4cd not read
# msg 00207.b9d4e94f1d5159f207cfe562194ab0c6 not read
# msg 00020.83ef024f76cc42b8245a683ed9b38406 not read
# msg 00360.fb2dbe3d751033f3e7b125b20ecdb897 not read
# msg 00320.b0cd1042164d8bd3ee1dab03a72edbc4 not read
# msg 01085.0d8db9468ce8ea76f81ebc03041cc467 not read
# msg 00454.cda832b92824f5cd7808db5d56ed9374 not read
# msg 01146.6352d04987d2f6a99be0d9beeb7d3e15 not read
# msg 01144.7ec9f643a792038e34d2830c9e42a6c6 not read
# msg 01186.0bbe8bddf593e88ef6b421b8e22caeab not read
# msg 00666.009d6116caed8ebd2b48febcea7b6c38 not read
# msg 01148.5d8311cf27db42e943c7f668e721db1b not read
# msg 01252.fb08e6249d158136cdbcb0ebc563793a not read
# msg 00202.28c767c7a895f6940228d3f1cbc95319 not read
# msg 00170.2368261c3f59066fc1b0c27c5495113e not read
# msg 01317.7fc86413a091430c3104b041a6525131 not read
# msg 00161.ff20c49f90c9405fc62064706ddcd615 not read
# msg 00016.bc1f434b566619637a0de033cd3380d1 not read
# msg 01192.5ff6d465f9c249d967776fc556e48f58 not read
# msg 01060.95d3e0a8c47b33d1533f18ac2c60c81a not read
# msg 00551.6b4053cfee95cebc96ffe991178ca79d not read
# msg 00498.637db80f2612123a12e1081ee90aff41 not read
# msg 01018.cb98ac59fae50ab0823aba7483d37d50 not read
# msg 00416.77c8eaf76f48ec6757aa82c847ecd7ef not read
# msg 00414.a46602860d900cb89e1edd5583ffdb55 not read
# msg 01056.6e58de5f5a270a1873f731774d760a80 not read
# msg 01147.d239448a535755047478e750e99c64b7 not read
# msg 00478.e7beb5a43fcf1ac2a87b4ce4fdcd9b32 not read
# msg 00343.2b1d47e0483fab66551f76a681455ff6 not read
# msg 00497.90e2604fc85ac552b46a924e795302a7 not read
# msg 00503.a066025f6fc03a6b0439c30d0d9bc419 not read
# msg 01171.e260c9a68b80500ebfae926e5430657b not read
# msg 00203.d235730a5eb66c00ea2c1ad65f415ad9 not read
# msg 00341.8bf7e41bff54bd779663d1f0a0fe3ed8 not read
# msg 01130.e0df582ca8cc2996eaf91157dbff4ee3 not read
# msg 00422.41c3bd638e1a077ba0c692579417f299 not read
# msg 01131.973943570b3b1ef6405a9d3cce5fc4fc not read
# msg 00813.6598e1ef9134cf77f48bca239e4ba2dc not read
# msg 01176.b62570033c5587aa1e0e805533cb1677 not read
# msg 01162.4b41142b91c1d93f1e8fcfa6f43e01bd not read
# msg 00036.6620b4d55c147aca7688250f16685d0d not read
# msg 01396.61983fbe6ec43f55fd44e30fce24ffa6 not read
# msg 00323.5cde61ff2c780291b15a802c513add1d not read
# msg 00664.28f4cb9fad800d0c7175d3a67e6c6458 not read
# msg 01205.784243c83be80461eb92f7d849b01c99 not read
# msg 01269.4b518a53f76da3fd4d469c5e2e557340 not read
# msg 01185.f32afd8b16453630bd5dc8eed551befe not read
# msg 00714.15dea0aa20430242a5527e0f928eb8d4 not read
# msg 01195.e7834b72cb6abc842f6d61f8cb08e346 not read
# msg 00310.5416fc4a71aadc904dbb4de56a299a71 not read
# msg 00393.dcfc9cf1d063ff68ace29c26e0394c05 not read
# msg 00555.219cc078f109a6eea18c579f143a8cef not read
# msg 01152.0306113715b577b682f6a529da8d45ab not read
# msg 00338.150c1aef21dcd741036532b8dad9d694 not read
# msg 00159.193c2e75773e8a7c7320c9974257da5a not read
# msg 01083.ecc77beb3f48b7be4481118a97b01b41 not read
# msg 00549.703d3fc9f56814c467616f8aac31d22d not read
# msg 01188.562fdb9dade3c2ef5e58ff18c04367bc not read
# msg 00548.9df9bd35a18874dcf39ec227a063b847 not read
# msg 00321.366bc08c72ec1996baa4065c0dada072 not read
# msg 00286.8cb982ac6ef73936ac83f89bf23fcd6b not read
# msg 00121.4c398f0106848ae9f9d3462c2296de17 not read
# msg 00027.c9e76a75d21f9221d65d4d577a2cfb75 not read
# msg 01289.10818e3dc6bacd14b05bd6521f8aaa27 not read
# msg 00276.78e7158a768394040c73be015a28de0a not read
# msg 00499.b66750ed646219a0524a648a061dfa67 not read

# %%
hardham=[]
targets_hardham=[]
hard_ham = os.listdir('./SpamAssassinMessages/hard_ham/')
for i in hard_ham:
    with open(os.path.join('./SpamAssassinMessages/hard_ham/',i), 'r') as f:
        try:
            x = email.message_from_file(f)
        except:
            print(f'msg {i} not read')
    mailType = x.get_content_type()
    textType = x.get_content_charset()
    if mailType == 'text/plain':
        hardham.append(x.get_payload())
        targets_hardham.append(0)
    elif mailType == 'text/html':
        tmp = BeautifulSoup(x.get_payload(), 'html.parser')
        tmp = tmp.text.replace('\n', ' ')
        hardham.append(tmp)
        targets_hardham.append(0)
    elif x.is_multipart():
         for j in x.walk():
            mailType = j.get_content_type()
            textType = j.get_content_charset()
            if mailType == "text/plain":
                hardham.append(j.get_payload())
                targets_hardham.append(0)
            elif mailType == "text/html":
                tmp = BeautifulSoup(j.get_payload(), 'html.parser')
                tmp = tmp.text.replace("\n"," ")
                hardham.append(tmp)
                targets_hardham.append(0)
    else:
        print(f'msg {i} not parsed')
        print(x.get_content_type())
        print(textType)
# Out:
# msg 0239.34e6b6125909c0d998370aacc82daefe not read
# msg 00223.14b06feeb8b03fed4e272140b8ed95f0 not read
# msg 00151.b352916ecff2b0ba1140d6898d789235 not read
# msg 0132.2893a03c7ec608a1416bef197a3ac13c not read
# msg 00191.5fd77d5b5c491cd7d2eaa004e78f5075 not read
# msg 00051.2dbf15ab121393e6ea3e30a8a12fa23b not read
# msg 0070.5deaf32310b325587f24b037b0453293 not read
# msg 00229.0870e13cd0b783d3d0b32826fa06bef3 not read
# msg 00232.3e89eaf26e6614545afbfc5d4ce13a44 not read
# msg 0164.82c660c5e1f778f96a4e36ab9aec323b not read
# msg 0230.cc7e33f6fb35ec73315649e151d66111 not read
# msg 00194.c7439a37e68aa99a7fb9242d46f02666 not read
# msg 00173.493449c83919771888e79bea2f0b4ac2 not read
# msg 0161.199b3947c40a3a72ab6407d91eee0557 not read
# msg 00181.01c5d96083c6e7770b1704791cf4bb3e not read
# msg 0180.d0c8419e4982b2fa0c716508fb783a68 not read
# msg 00244.6b536755550a406301a4dbd482341125 not read
# msg 00192.660d3367a86966f1a2a38d328215c905 not read
# msg 0157.09827ed42b5f694067929fc00393630e not read
# msg 0242.cc7e33f6fb35ec73315649e151d66111 not read
# msg 00108.c616dad1b875643b5f48452beadf54b0 not read
# msg 0191.47a4267102621d60e7de985f0f738f96 not read
# msg 00177.81236553338cae51575b54c6a07426f9 not read
# msg 00179.e07465b40c68c228dfb7133d8788e5cf not read
# msg 0171.786d4f37f37d9043eb4fc2d3521b78b4 not read
# msg 0196.9dc01775acba34e580ddf9a56ea6891e not read
# msg 00247.42534d5df0700cb2adf240556c539947 not read
# msg 0177.7bf03ee9001454f9f3b4d258cd926098 not read
# msg 00161.786d4f37f37d9043eb4fc2d3521b78b4 not read
# msg 0139.37c6b32ba39eaa510af007deef725ec2 not read
# msg 00235.942d5701daf62963c60e4a22ac76203b not read
# msg 0141.82c48bdf90cb29370a2783a3523f3b04 not read
# msg 00186.fe677caf46d7739f8b560388e1cdbbe2 not read
# msg 0121.05eb8cf2ea8592ffd4be29698e07f67b not read
# msg 0146.e49cd86bb6e497e11c9ca1ca27cd5893 not read
# msg 00174.62cbd01979122b7c30b5eb301b834db2 not read
# msg 00136.5a3b167888ad2dddf950359e492b953c not read
# msg 00180.c48e764a71e8baa907f4f623cbbf9b80 not read
# msg 0190.5a3b0581835fba34b28985bbea2c8f41 not read
# msg 00202.8482d07f3281465b273327bb83bd9a39 not read
# msg 0162.5258f5bbb6d86187bbd7b58851ce3b06 not read
# msg 0163.0123b1afbae948c7fa80a8ab79786e16 not read
# msg 0136.bd2d54da3eaadd1f4428f48a28844d39 not read
# msg 00083.5c1fe69b6ebb360baac59ddca2b9bda0 not read
# msg 0227.34e6b6125909c0d998370aacc82daefe not read
# msg 00224.0b10471bd4bcd9b5aad01f0431f72d9f not read
# msg 00193.0ec2d3762629686bdebde22f730a15e9 not read
# msg 0095.3ab54d86bb56d59bdf2d4a1cd5626357 not read
# msg 00226.54521695be23019d664e33a1a7753355 not read
# msg 00006.3409dec8ca4fcf2d6e0582554473b5c9 not read
# msg 0038.9fc6b97854121a9c1dc34b0160620558 not read
# msg 00237.2ed2cce324d7ce55d991022301ab5923 not read
# msg 00158.8042a8d7b2a93ebdee1df8239cfea2b0 not read
# msg 00249.b9183324a9726e8b6c8779045a921243 not read
# msg 0184.290d2aac65ac6b71689d7f223f1bb5fd not read
# msg 00009.ddea79a02a9978cb3dafef3c05ff37a6 not read
# msg 00242.fc258e3fb7c6c86571243691e28c1921 not read
# msg 0158.ea156bc818540dd76784fac2f6969783 not read
# msg 0173.7020d254bb5a5582cac3c174523e6f77 not read
# msg 0194.d25929908330db4d7f1d959a295651e0 not read
# msg 00241.4e5262894127344225abfc680c35e3d3 not read
# msg 0181.4750eb0bfa983cb33844255f8f6a2094 not read

# %%
targets_ham = targets_hardham + targets_easyham + targets_easyham2
ham = easyham + easyham2+ hardham

# %%
mail_df = pd.DataFrame(zip(ham, targets_ham), columns=['content', 'classify'])
mail_df.head()
# Out:
#                                              content  classify
# 0  URL: http://www.newsisfree.com/click/-1,838114...         0
# 1  URL: http://www.newsisfree.com/click/-1,838114...         0
# 2  \nIn a message dated 9/24/2002 11:24:58 AM, ja...         0
# 3  Hiya, I always seem to get errors when I do an...         0
# 4  \nI don't know how one can expect better and m...         0

# %%
mail_df.shape
# Out:
# (7098, 2)

# %%
spamlist=[]
targets_spam=[]
spam = os.listdir('./SpamAssassinMessages/spam/')
for i in spam:
    with open(os.path.join('./SpamAssassinMessages/spam/',i), 'r', encoding="ISO-8859-1") as f:
        try:
            x = email.message_from_file(f)
        except:
            print(f'msg {i} not read')
    mailType = x.get_content_type()
    textType = x.get_content_charset()
    if mailType == 'text/plain':
        spamlist.append(x.get_payload())
        targets_spam.append(1)
    elif mailType == 'text/html':
        tmp = BeautifulSoup(x.get_payload(), 'html.parser')
        tmp = tmp.text.replace('\n', ' ')
        spamlist.append(tmp)
        targets_spam.append(1)
    elif mailType == "multipart/alternative":
        for i in x.walk():
            if i.get_content_type() == 'text/plain':
                spamlist.append(i.get_payload())
                targets_spam.append(1)
            elif i.get_content_type() == 'text/html':
                tmp = BeautifulSoup(i.get_payload(), 'html.parser')
                tmp = tmp.text.replace('\n', ' ')
                spamlist.append(tmp)
                targets_spam.append(1)
    elif x.is_multipart():
         for j in x.walk():
            mailType = j.get_content_type()
            textType = j.get_content_charset()
            if mailType == "text/plain":
                spamlist.append(j.get_payload())
                targets_spam.append(1)
            elif mailType == "text/html":
                tmp = BeautifulSoup(j.get_payload(), 'html.parser')
                tmp = tmp.text.replace("\n"," ")
                spamlist.append(tmp)
                targets_spam.append(1)
    else:
        print(f'msg {i} not parsed')
        print(x.get_content_type())
        print(textType)

# %%
spamlist_2=[]
targets_spam_2=[]
spam_2 = os.listdir('./SpamAssassinMessages/spam_2/')
for i in spam_2:
    with open(os.path.join('./SpamAssassinMessages/spam_2/',i), 'r', encoding="ISO-8859-1") as f:
        try:
            x = email.message_from_file(f)
        except:
            print(f'msg {i} not read')
    mailType = x.get_content_type()
    textType = x.get_content_charset()
    if mailType == 'text/plain':
        spamlist_2.append(x.get_payload())
        targets_spam_2.append(1)
    elif mailType == 'text/plain charset=us-ascii':
        spamlist_2.append(x.get_payload())
        targets_spam_2.append(1)
    elif mailType == 'text/html':
        tmp = BeautifulSoup(x.get_payload(), 'html.parser')
        tmp = tmp.text.replace('\n', ' ')
        spamlist_2.append(tmp)
        targets_spam_2.append(1)
    elif mailType == "multipart/alternative":
        for i in x.walk():
            if i.get_content_type() == 'text/plain':
                spamlist_2.append(i.get_payload())
                targets_spam_2.append(1)
            elif i.get_content_type() == 'text/html':
                tmp = BeautifulSoup(i.get_payload(), 'html.parser')
                tmp = tmp.text.replace('\n', ' ')
                spamlist_2.append(tmp)
                targets_spam_2.append(1)
    elif x.is_multipart():
         for j in x.walk():
            mailType = j.get_content_type()
            textType = j.get_content_charset()
            if mailType == "text/plain":
                spamlist_2.append(j.get_payload())
                targets_spam_2.append(1)
            elif mailType == "text/html":
                tmp = BeautifulSoup(j.get_payload(), 'html.parser')
                tmp = tmp.text.replace("\n"," ")
                spamlist_2.append(tmp)
                targets_spam_2.append(1)
    else:
        print(f'msg {i} not parsed')
        print(x.get_content_type())
        print(textType)

# %%
spam_list = spamlist_2 + spamlist
targets_spam_list = targets_spam_2 + targets_spam

# %%
spam_df = pd.DataFrame(zip(spam_list, targets_spam_list), columns=['content', 'classify'])
spam_df.head()
# Out:
#                                              content  classify
# 0  Venez rencontrer l'ame soeur sur LOVEIMPACT.co...         1
# 1       =20      Rencontrez=20         l'amour po...         1
# 2       A man endowed with a 7-8" hammer is simpl...         1
# 3  Date:May 16,2002. \nEmail:edum@hkem.com. \n\nD...         1
# 4  \n<HTML>\n<BODY>\n\nOWN YOUR VERY OWN FREE CAS...         1

# %%
spam_df.shape
# Out:
# (2619, 2)

# %%
mail_all = pd.concat([mail_df, spam_df], axis=0)
#mail_all.drop_duplicates(inplace=True)

# %%
mail_all.shape
# Out:
# (9717, 2)

# %%
mail_all
# Out:
#                                                 content  classify
# 0     URL: http://www.newsisfree.com/click/-1,838114...         0
# 1     URL: http://www.newsisfree.com/click/-1,838114...         0
# 2     \nIn a message dated 9/24/2002 11:24:58 AM, ja...         0
# 3     Hiya, I always seem to get errors when I do an...         0
# 4     \nI don't know how one can expect better and m...         0
# ...                                                 ...       ...
# 2614  ààªÍ¶¯ÄÔÇ¤ªäêé\nµ¶ÝÆààÌR...         1
# 2615   Beautiful,Custom Websites for $399 Complete! ...         1
# 2616  There is NO stumbling on to it! \n\nThe greate...         1
# 2617  Lowest rates available for term life insurance...         1
# 2618  1) Fight The Risk of Cancer!\nhttp://www.adcli...         1
#
# [9717 rows x 2 columns]

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/matt/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /Users/matt/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#Change letters to lowercase
#Remove punctuation 
#Remove stopwords
#Remove digits
#Use stemmer and Lemmatization
stemmer = SnowballStemmer('english')
lemmatizer = WordNetLemmatizer()
def clean_text(text):
    text = text.lower()
    text = [x for x in text if x not in string.punctuation]
    text = [i for i in text if not i.isdigit()]
    text = ''.join(text)
    words = [y for y in text.split() if y not in stopwords.words('english')]
    words= [lemmatizer.lemmatize(j) for j in words]
    clean_words = ' '.join([stemmer.stem(z) for z in words])
    return clean_words

# %%
mail_all['content'].head().apply(clean_text)
# Out:
# 0    url httpwwwnewsisfreecomclick date art fourth ...
# 1    url httpwwwnewsisfreecomclick date art fourth ...
# 2    messag date jamesrbestcom write situat wouldnt...
# 3    hiya alway seem get error apt updat problem re...
# 4    dont know one expect better secur code communi...
# Name: content, dtype: object

# %%
#Shuffle the data frame
mail_all = mail_all.sample(frac=1)

# %%
#Use CountVectorizer
cv = CountVectorizer(analyzer='word')
X= cv.fit_transform(mail_all['content'])
y= mail_all['classify']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, shuffle=True, test_size=0.2, stratify=y)

# %%
X_train
# Out:
# <7773x80605 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1117463 stored elements in Compressed Sparse Row format>

# %%
#Use Multinomial Naive Bayes
NBclassifier = MultinomialNB().fit(X_train, y_train)
pred = NBclassifier.predict(X_test)

# %%
print(classification_report(y_test, pred))
print('\n')
print('Confusion Matrix: \n', confusion_matrix(y_test, pred))
print('\n')
print('Accuracy: \n', accuracy_score(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1420
#            1       0.99      0.97      0.98       524
#
#     accuracy                           0.99      1944
#    macro avg       0.99      0.98      0.99      1944
# weighted avg       0.99      0.99      0.99      1944
#
#
#
# Confusion Matrix:
#  [[1417    3]
#  [  18  506]]
#
#
# Accuracy:
#  0.9891975308641975

# %%
#Use KMean clustering to create new features before applying Naive Bayes
#Use elbow method to get the optimal number of clusters
wcss=[]

for i in range(2,28):
    cls=KMeans(n_clusters=i, init='k-means++',random_state=5)
    cls.fit(X)
    wcss.append(cls.inertia_)


f,ax=plt.subplots(figsize=(8,8))
plt.subplot(1,1,1)
plt.plot(range(2,28),wcss)
plt.title('The Elbow Method for Cluster')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')

# %%
#Use n=10 clusters to do KMean clustering
cls=KMeans(n_clusters=5, init='k-means++',random_state=1)
cls.fit(X_train)
#Append the new cluster feature column to spase matrix
X_train_new = scipy.sparse.hstack((X_train, cls.predict(X_train)[:,None])).A 
X_test_new = scipy.sparse.hstack((X_test, cls.predict(X_test)[:,None])).A
#X_train_new.shape

# %%
#Use X_new to fit Naive Bayes model
NBclassifier = MultinomialNB().fit(X_train_new, y_train)
pred_cluster = NBclassifier.predict(X_test_new)

# %%
print(classification_report(y_test, pred_cluster))
print('\n')
print('Confusion Matrix: \n', confusion_matrix(y_test, pred_cluster))
print('\n')
print('Accuracy: \n', accuracy_score(y_test, pred_cluster))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1420
#            1       0.99      0.97      0.98       524
#
#     accuracy                           0.99      1944
#    macro avg       0.99      0.98      0.99      1944
# weighted avg       0.99      0.99      0.99      1944
#
#
#
# Confusion Matrix:
#  [[1417    3]
#  [  18  506]]
#
#
# Accuracy:
#  0.9891975308641975

# %% [markdown]
# ### End of the case study

# %%
#Use KNN clustering
knn = KNeighborsClassifier().fit(X_train, y_train)
pred_knn = knn.predict(X_test)

# %%
print(classification_report(y_test, pred_knn))
print('\n')
print('Confusion Matrix: \n', confusion_matrix(y_test, pred_knn))
print('\n')
print('Accuracy: \n', accuracy_score(y_test, pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.95      1420
#            1       0.85      0.92      0.88       524
#
#     accuracy                           0.94      1944
#    macro avg       0.91      0.93      0.92      1944
# weighted avg       0.94      0.94      0.94      1944
#
#
#
# Confusion Matrix:
#  [[1337   83]
#  [  43  481]]
#
#
# Accuracy:
#  0.9351851851851852

# %%
#Use TFIDFvectorizer
X= TfidfVectorizer(analyzer=clean_text).fit_transform(mail_all['content'])
y= mail_all['classify']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, shuffle=True, test_size=0.2, stratify=y)

# %%
NBclassifier = MultinomialNB().fit(X_train, y_train)
pred = NBclassifier.predict(X_test)

# %%
print(classification_report(y_test, pred))
print('\n')
print('Confusion Matrix: \n', confusion_matrix(y_test, pred))
print('\n')
print('Accuracy: \n', accuracy_score(y_test, pred))

# %%
knn = KNeighborsClassifier().fit(X_train, y_train)
pred_knn = knn.predict(X_test)

# %%
print(classification_report(y_test, pred_knn))
print('\n')
print('Confusion Matrix: \n', confusion_matrix(y_test, pred_knn))
print('\n')
print('Accuracy: \n', accuracy_score(y_test, pred_knn))

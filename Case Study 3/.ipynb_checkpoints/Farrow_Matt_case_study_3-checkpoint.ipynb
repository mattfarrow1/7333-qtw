# %% [markdown]
# # Case Study 3
#
# Build a spam classifier using naive Bayes and clustering. You will have to create your own dataset from the input messages. Be sure to document how you created your dataset.

# %%
# Import standard libraries
import pandas as pd
import numpy as np

# Import visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Import sklearn libraries
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, silhouette_samples, silhouette_score, recall_score, roc_curve, auc, precision_score, f1_score
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV, cross_val_predict, cross_validate, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
import sklearn.cluster as cluster
from sklearn.naive_bayes import ComplementNB

# Import nltk libraries
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import SnowballStemmer

# Import HTML processing libraries
from html.parser import HTMLParser
from bs4 import BeautifulSoup

# Import scipy libraries
import scipy
from scipy.sparse import csr_matrix

# Import other libraries
from collections import Counter
import string
import os
import re
import email
import warnings
from wordcloud import WordCloud

warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Examine the Data

# %%
# Look at the contents of the current directory
os.listdir('.')
# Out:
# ['.DS_Store',
#  'CleanShot 2022-05-22 at 12.45.01@2x.png',
#  'SpamAssassinMessages',
#  '.ipynb_checkpoints',
#  'Farrow_Matt_case_study_3.ipynb']

# %%
# Look at the contents of the `SpamAssassinMessages` folder
os.listdir('./SpamAssassinMessages')
# Out:
# ['spam', 'hard_ham', 'spam_2', 'easy_ham', 'easy_ham_2']

# %%
# Glance at one of the emails to understand the raw data
os.system('cat ./SpamAssassinMessages/easy_ham/2551.3b1f94418de5bd544c977b44bcc7e740')
# Out:
# From rssfeeds@jmason.org  Thu Oct 10 12:32:34 2002
# Return-Path: <rssfeeds@example.com>
# Delivered-To: yyyy@localhost.example.com
# Received: from localhost (jalapeno [127.0.0.1])
# 	by jmason.org (Postfix) with ESMTP id 89EE616F03
# 	for <jm@localhost>; Thu, 10 Oct 2002 12:32:33 +0100 (IST)
# Received: from jalapeno [127.0.0.1]
# 	by localhost with IMAP (fetchmail-5.9.0)
# 	for jm@localhost (single-drop); Thu, 10 Oct 2002 12:32:33 +0100 (IST)
# Received: from dogma.slashnull.org (localhost [127.0.0.1]) by
#     dogma.slashnull.org (8.11.6/8.11.6) with ESMTP id g9A84QK14194 for
#     <jm@jmason.org>; Thu, 10 Oct 2002 09:04:26 +0100
# Message-Id: <200210100804.g9A84QK14194@dogma.slashnull.org>
# To: yyyy@example.com
# From: newscientist <rssfeeds@example.com>
# Subject: Critical US satellites could be hacked
# Date: Thu, 10 Oct 2002 08:04:26 -0000
# Content-Type: text/plain; encoding=utf-8
# X-Spam-Status: No, hits=-959.4 required=5.0
# 	tests=AWL,DATE_IN_PAST_03_06,T_NONSENSE_FROM_00_10,
# 	      T_NONSENSE_FROM_10_20,T_NONSENSE_FROM_20_30,
# 	      T_NONSENSE_FROM_30_40,T_NONSENSE_FROM_40_50,
# 	      T_NONSENSE_FROM_50_60,T_NONSENSE_FROM_60_70,
# 	      T_NONSENSE_FROM_70_80,T_NONSENSE_FROM_80_90,
# 	      T_NONSENSE_FROM_90_91,T_NONSENSE_FROM_91_92,
# 	      T_NONSENSE_FROM_92_93,T_NONSENSE_FROM_93_94,
# 	      T_NONSENSE_FROM_94_95,T_NONSENSE_FROM_95_96,
# 	      T_NONSENSE_FROM_96_97,T_NONSENSE_FROM_97_98,
# 	      T_NONSENSE_FROM_98_99,T_NONSENSE_FROM_99_100
# 	version=2.50-cvs
# X-Spam-Level:
#
# URL: http://www.newsisfree.com/click/-3,8708820,1440/
# Date: Not supplied
#
# Military communications could be jammed or intercepted and satellites thrown
# off course or destroyed, a new US study warns
# 0

# %% [markdown]
# # Trying Other Code

# %%
from os import listdir, getcwd, chdir
from os.path import isfile, join, dirname, realpath


def get_cwd():
    active_dir = getcwd()
    return active_dir

def main():
    
    get_cwd()
    
    directories = [
            'easy_ham',
            'easy_ham_2',
            'hard_ham',
            'spam',
            'spam_2'
            ] 
    
    res_frame = pd.DataFrame()
    
    emails = []

    bodies = []
        
    for d in directories:
        mypath = getcwd() + '/data/' + d + '/'
        onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
    
        try:
            onlyfiles.remove('.DS_Store')
        except:
            pass
        
        for file in onlyfiles:
            with open(mypath + file, encoding='latin1') as f:
                lines = f.readlines()
                f.close()
            
            with open(mypath + file, encoding='latin1') as f:
                body = f.read()
                f.close()
                
            msg = email.message_from_string(str(body))
            tmpStr = ''
            
            if msg.is_multipart():
                for payload in msg.get_payload():
                    tmpStr = ' '.join(str(payload.get_payload()))
                bodies.append(tmpStr)
            else:
                bodies.append(str(msg.get_payload()))
                
            in_reply_count = 0
            sub_line_all_caps = 0
            attachments = 0
            subject_line = []
            n_lines = 0
            blank_lines = []
            
            for line in lines:

                n_lines += 1
                if "Subject: Re: " in line:
                   in_reply_count += 1
                if "Subject: " in line:
                   s_line = line.strip().replace('Subject: ','')
                   s_line = ''.join(e for e in s_line if e.isalnum())
                   num_upper = sum(1 for c in s_line if c.isupper())
                   ttl_chars = len(s_line)
                   if num_upper == ttl_chars:
                       sub_line_all_caps += 1
                   subject_line.append(s_line)
                if "content-type: multipart" in line.lower():
                   attachments += 1
                if line == "\n":
                   blank_lines.append(n_lines)
        
            temp_frame = pd.DataFrame({
                        'directory':d,    
                        'filename':file,
                        'is_spam':['Y' if 'spam' in d else 'N'],
                        'in_reply': ['Y' if in_reply_count > 0 else 'N'], 
                        'subj_caps': ['Y' if sub_line_all_caps > 0 else 'N'], 
                        'attachments': ['Y' if attachments > 0 else 'N'],
                        'body_lines': [0 if len(blank_lines) == 0 else min(blank_lines)]
                        }, index=[0])
           
            res_frame = res_frame.append(temp_frame, ignore_index=True)

            # Append body of email to collection
            text = ' '.join(lines)
            emails.append(text)
    
    # Add emails
    return res_frame, emails, bodies

df, emails, bodies = main()

# %%
df.info()
df.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9353 entries, 0 to 9352
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   directory    9353 non-null   object
#  1   filename     9353 non-null   object
#  2   is_spam      9353 non-null   object
#  3   in_reply     9353 non-null   object
#  4   subj_caps    9353 non-null   object
#  5   attachments  9353 non-null   object
#  6   body_lines   9353 non-null   int64
# dtypes: int64(1), object(6)
# memory usage: 511.6+ KB
#      directory                                filename is_spam in_reply  \
# 4649  easy_ham  01701.a28b76746a64d3d352375a462f4f8404       N        N
# 4564  easy_ham  01537.ded3233d7649ef141c30e4cc1349f790       N        Y
# 4484  easy_ham  00864.95da38aac2ee9c6c8d36d0f2f1e8c8e5       N        Y
# 7310      spam   0410.be908008e0e27722a177b289227f5fc1       Y        N
# 4767  easy_ham   1223.6f20be4e92f37aaa7117c0a30a19207d       N        Y
#
#      subj_caps attachments  body_lines
# 4649         N           N          10
# 4564         N           N          33
# 4484         N           N          44
# 7310         N           Y          28
# 4767         N           N          66

# %%
df = df.replace(['Y','N'],[1,0])
df.sample(5)
# Out:
#        directory                                filename  is_spam  in_reply  \
# 5132  easy_ham_2  00423.29f3d90625a1bf69a8620f78f15246a3        0         0
# 7435        spam  00306.729a42414b91e9b2bddf273c514c50d7        1         0
# 7618        spam   0057.92fdae44bdd1d9e5461eef3c852dfd23        1         0
# 6036  easy_ham_2  00574.ca8de7c19bacedefb060405b55d13c29        0         0
# 3508    easy_ham   0293.24bc65777fdb12d17b16e3976c1f7c17        0         1
#
#       subj_caps  attachments  body_lines
# 5132          0            0          43
# 7435          0            0          24
# 7618          0            0          30
# 6036          0            1          55
# 3508          0            0          44

# %% [markdown]
# ## Clean up Text

# %%
stop_words = nltk.corpus.stopwords.words('english')

def normalize_document(doc):
    # lowercase and remove special characters to form a normalized document
    doc = re.sub(r'[^a-zA-Z0-9\s]', ' ', doc, re.I|re.A)
    doc = doc.lower()
    doc = doc.strip()

    # tokenize document
    tokens = nltk.word_tokenize(doc)
    
    # filter out stop words
    filtered_tokens = [token for token in tokens if token not in stop_words]

    # Remove numbers
    filtered_tokens = [token for token in filtered_tokens if not token.isdigit()]

    # Remove short tokens
    filtered_tokens = [token for token in filtered_tokens if len(token) > 2]

    # re-create a normalized document
    doc = ' '.join(filtered_tokens)
    return doc

normalize_text = np.vectorize(normalize_document)
norm_text = normalize_text(emails)

print(type(norm_text),len(norm_text))
# Out:
# <class 'numpy.ndarray'> 9353

# %% [markdown]
# ## Convert to Dataframe

# %%
norm_text_2 = pd.DataFrame(norm_text)
directory = pd.DataFrame(df['directory'])
combined_df = pd.concat([norm_text_2,directory],axis=1)
combined_df.columns = ['text','directory']
combined_df['text'] = combined_df['text'].apply(lambda x: x.split())
combined_df
# Out:
#                                                    text directory
# 0     [rssfeeds, jmason, org, mon, sep, return, path...  easy_ham
# 1     [fork, admin, xent, com, tue, sep, return, pat...  easy_ham
# 2     [fork, admin, xent, com, tue, sep, return, pat...  easy_ham
# 3     [rpm, list, admin, freshrpms, net, mon, sep, r...  easy_ham
# 4     [secprog, return, jmason, org, securityfocus, ...  easy_ham
# ...                                                 ...       ...
# 9348  [687ifsuy, bol, com, tue, aug, return, path, 6...    spam_2
# 9349  [mraimecoilcipc, msn, com, mon, jul, return, p...    spam_2
# 9350  [fork, admin, xent, com, thu, aug, return, pat...    spam_2
# 9351  [niddeel, hotmail, com, tue, aug, return, path...    spam_2
# 9352  [received, actioncouriers, com, linux, midrang...    spam_2
#
# [9353 rows x 2 columns]

# %% [markdown]
# ## TfIDF Matrix

# %%
tf = TfidfVectorizer(ngram_range=(1,3), min_df=5, max_df=.8, stop_words=stop_words, norm='l2')
tf_matrix = tf.fit_transform(norm_text)

print(tf_matrix.shape)
# Out:
# (9353, 166742)

# %% [markdown]
# ## Topic Modeling

# %%
from gensim.corpora import Dictionary
from gensim.models.coherencemodel import CoherenceModel
from gensim.models.ldamodel import LdaModel
import little_mallet_wrapper as lmw

os.environ['MALLET_HOME'] = '/Users/matt/mallet-2.0.8'
path_to_mallet = '/Users/matt/mallet-2.0.8/bin/mallet'

# Define training data
combined_df['text_2'] = combined_df['text'].apply(lambda x: ' '.join(x))
training_data = [lmw.process_string(t) for t in combined_df['text_2']]
training_data = [d for d in training_data if d.strip()]

# Number of topics that user specifies
num_topics = 15

# Define output directory
output_directory_path = '/Users/matt/Documents/GitHub/7333-qtw/Case Study 3'

topic_keys, topic_distributions = lmw.quick_train_topic_model(path_to_mallet, 
                                                              output_directory_path, 
                                                              num_topics, 
                                                              training_data)
# Out:
# Importing data...
# Complete
# Training topic model...
# Mallet LDA: 15 topics, 4 topic bits, 1111 topic mask
# Data loaded.
# max tokens: 19655
# total tokens: 4823074
# <10> LL/token: -7.58047
# <20> LL/token: -7.19166
# <30> LL/token: -7.1065
# <40> LL/token: -7.0689
#
# 0	0.33333	http www com net html asp radio org weblogs NUM php com/NUM blogspot weblog blog htm web news netnoir admanmail
# 1	0.33333	font size color face NUM nbsp arial align center verdana style div sans serif table helvetica href span com width
# 2	0.33333	com xent fork NUM list localhost received org sep mailto admin esmtp subject http postfix request taint spamassassin net version
# 3	0.33333	bNUM aNUM dNUM cNUM eNUM fNUM commits tim sep date net NUM comcast python spambayes spam message return delivery path
# 4	0.33333	com received localhost zzzz net yahoo aug org netnoteinc content mail esmtp smtp mon subject http message jul labs webnote
# 5	0.33333	NUM one people get money email make time free business mail like would send want address report order internet work
# 6	0.33333	http www href nbsp lockergnome com html NUM class target table web blank type title border value text name input
# 7	0.33333	NUM width http height src img gif font www border cnet href bgcolor com/b table online size clickthru com/click zdnet
# 8	0.33333	NUM com exmh org redhat users taint spamassassin workers listman received example list localhost mxNUM sep aug esmtp int mailto
# 9	0.33333	NUM net freshrpms rpm list zzzlist egwn localhost received http esmtp lists mailto subject admin org oct request version net/mailman/listinfo/rpm
# 10	0.33333	NUMd NUM NUMdNUM width http height NUMe option www value table src img border size gif align name type bgcolor
# 11	0.33333	NUM net pro jul ssz cypherpunks minder cpunks einstein zoo petting received sightings envelope cdt waste locust NUMxdeadbeef sun com
# 12	0.33333	NUM net sourceforge linux received localhost ilug spamassassin list org example users aug esmtp talk razor admin lists com lugh
# 13	0.33333	said world new security states also company would government united technology one companies years first news people market could two
# 14	0.33333	org localhost oct com received sep dogma slashnull jmason jalapeno ist taint esmtp date spamassassin rssfeeds yyyy example http tue
#
# <50> LL/token: -7.05075
# <60> LL/token: -7.03783
# <70> LL/token: -7.0301
# <80> LL/token: -7.02473
# <90> LL/token: -7.02183
#
# 0	0.33333	http www com net html radio asp org NUM weblogs com/NUM php blogspot weblog blog news web htm netnoir admanmail
# 1	0.33333	font size color NUM face nbsp arial align center verdana style div sans table serif helvetica width span com href
# 2	0.33333	com xent fork NUM localhost list received org sep mailto admin esmtp subject http postfix request taint spamassassin net pdt
# 3	0.33333	bNUM aNUM dNUM cNUM eNUM fNUM commits tim comcast sep date python spambayes NUM spam return net message path delivery
# 4	0.33333	com received localhost net zzzz yahoo aug org netnoteinc content esmtp mail smtp mon http subject jul message labs return
# 5	0.33333	NUM one people get email money make time free business mail would like want send work report order address internet
# 6	0.33333	http www href nbsp lockergnome com html NUM class table target blank web type border title value text name input
# 7	0.33333	NUM width http height src img gif font www border cnet href bgcolor com/b table online size clickthru com/click zdnet
# 8	0.33333	NUM com exmh org redhat users taint spamassassin workers listman received example list localhost mxNUM sep aug esmtp int mailto
# 9	0.33333	NUM net freshrpms rpm list zzzlist egwn localhost received http esmtp lists mailto subject admin org oct version request net/mailman/listinfo/rpm
# 10	0.33333	NUMd NUM NUMdNUM width http height NUMe www table option size src value img border align gif bgcolor name type
# 11	0.33333	NUM net pro jul ssz cypherpunks minder cpunks einstein zoo petting received sightings cdt waste envelope locust com esmtp NUMxdeadbeef
# 12	0.33333	NUM net sourceforge linux received localhost ilug spamassassin list org example users aug esmtp talk razor com admin lists lugh
# 13	0.33333	said world company new security states also government united technology would companies one people years first could news president market
# 14	0.33333	org localhost oct com received dogma slashnull jmason sep jalapeno taint ist esmtp rssfeeds spamassassin date example yyyy http tue
#
# <100> LL/token: -7.01944
# <110> LL/token: -7.01711
# <120> LL/token: -7.01448
# <130> LL/token: -7.0122
# <140> LL/token: -7.01049
#
# 0	0.33333	http www com net radio html org NUM asp weblogs com/NUM php blogspot weblog blog news netnoir admanmail htm web
# 1	0.33333	font size color face NUM nbsp arial align center verdana style div sans width table helvetica serif span href com
# 2	0.33333	com xent fork NUM localhost list received org sep mailto admin esmtp subject http postfix request taint spamassassin net version
# 3	0.33333	bNUM dNUM cNUM aNUM eNUM fNUM commits tim comcast sep date NUM python spambayes net spam return message skip content
# 4	0.33333	com received localhost net zzzz yahoo aug org netnoteinc content esmtp mail smtp http mon subject jul message sep labs
# 5	0.33333	NUM one people get email money make mail time business would like free send address order work report want software
# 6	0.33333	http www href nbsp lockergnome com html NUM class table target blank border web type title name value text input
# 7	0.33333	NUM width http height src img gif font www border cnet href bgcolor com/b table online clickthru com/click size zdnet
# 8	0.33333	NUM com exmh org redhat users taint spamassassin workers listman received example list localhost mxNUM sep aug esmtp int subject
# 9	0.33333	NUM net freshrpms rpm list zzzlist egwn localhost received http esmtp lists mailto subject admin org oct version request net/mailman/listinfo/rpm
# 10	0.33333	NUMd NUM NUMdNUM width http height NUMe www size table option value src img border align font gif bgcolor name
# 11	0.33333	NUM net pro jul ssz cypherpunks minder cpunks einstein received zoo petting sightings envelope cdt waste locust NUMxdeadbeef lists com
# 12	0.33333	NUM net sourceforge linux received localhost ilug spamassassin list org example aug users esmtp talk razor com admin lists lugh
# 13	0.33333	said world company security states new also government technology united companies would one years first people could xml news president
# 14	0.33333	org localhost oct com received slashnull dogma jmason sep jalapeno taint ist esmtp date rssfeeds spamassassin example http yyyy tue
#
# <150> LL/token: -7.01141
# <160> LL/token: -7.01101
# <170> LL/token: -7.0093
# <180> LL/token: -7.00946
# <190> LL/token: -7.00807
#
# 0	0.33333	http www com net radio html NUM org asp weblogs com/NUM blogspot php weblog blog news netnoir admanmail web htm
# 1	0.33333	font size color face NUM nbsp arial align center verdana style div width sans table helvetica serif span com href
# 2	0.33333	com xent fork NUM list localhost received org sep mailto admin esmtp subject http postfix request taint spamassassin net version
# 3	0.33333	bNUM dNUM aNUM cNUM eNUM fNUM commits tim comcast NUM sep net date python spambayes spam message return skip delivery
# 4	0.33333	com received localhost net yahoo zzzz aug org netnoteinc content esmtp mail mon smtp http subject jul message return date
# 5	0.33333	NUM one people get email money make mail time would business like com free send address work order need report
# 6	0.33333	http www href nbsp lockergnome com html NUM table class target border blank type title web value name text input
# 7	0.33333	NUM width http height src img gif font www border cnet href com/b bgcolor online table clickthru com/click size zdnet
# 8	0.33333	NUM com exmh org redhat users taint spamassassin workers listman received example list localhost mxNUM sep aug esmtp int mailto
# 9	0.33333	NUM net freshrpms rpm list zzzlist egwn localhost received http esmtp lists mailto subject admin org oct version request net/mailman/listinfo/rpm
# 10	0.33333	NUMd NUM NUMdNUM width http height NUMe www size table option value img src font border align gif bgcolor name
# 11	0.33333	NUM net pro jul ssz cypherpunks minder cpunks einstein received zoo petting sightings waste cdt envelope locust com NUMxdeadbeef esmtp
# 12	0.33333	NUM net sourceforge linux received localhost ilug spamassassin list org example users aug esmtp talk razor admin com lists lugh
# 13	0.33333	said world company security also new states government technology united would companies one people first years could xml news president
# 14	0.33333	org localhost oct com received dogma slashnull jmason sep jalapeno taint ist esmtp date rssfeeds spamassassin example yyyy http tue
# <200> LL/token: -7.00806
# [beta: 0.01795]
# <210> LL/token: -6.99339
# [beta: 0.01853]
# <220> LL/token: -6.96827
# [beta: 0.01873]
# <230> LL/token: -6.95039
# [beta: 0.01885]
# <240> LL/token: -6.94106
#
# 0	0.01218	http www com net radio html NUM org weblogs asp com/NUM blogspot php blog weblog admanmail netnoir web news jeweldive
# 1	0.03603	font size NUM color face nbsp arial align center verdana style width div sans table span serif helvetica com href
# 2	0.08897	com xent fork NUM localhost list received org sep mailto admin esmtp subject http postfix request taint spamassassin net version
# 3	0.01314	bNUM dNUM aNUM cNUM eNUM fNUM commits tim NUM comcast sep net python spambayes date spam return skip NUMt content
# 4	0.13176	com received localhost net yahoo zzzz aug org netnoteinc NUM content esmtp mail http mon smtp subject jul sep message
# 5	0.21744	NUM one people get email money make mail time would like com free business send want order work received address
# 6	0.03899	http www href nbsp lockergnome com html NUM table class target border blank title type web name value input text
# 7	0.01823	NUM width http height src img gif font www cnet border href com/b bgcolor online table clickthru com/click size zdnet
# 8	0.02765	NUM com exmh org redhat users taint spamassassin workers listman received example list localhost mxNUM sep aug esmtp int mailto
# 9	0.02856	NUM net freshrpms rpm list zzzlist egwn localhost received http esmtp lists mailto admin subject org oct net/mailman/listinfo/rpm request version
# 10	0.0219	NUMd NUM NUMdNUM width http height NUMe size www font table src img option value border align gif bgcolor com
# 11	0.01406	NUM net pro jul ssz cypherpunks minder cpunks einstein zoo petting received sightings locust waste envelope cdt NUMxdeadbeef esmtp list
# 12	0.087	NUM net sourceforge linux localhost received ilug list org spamassassin example users aug com esmtp talk razor admin lists lugh
# 13	0.10122	said world company security states new government also united technology people would one companies years xml first president law could
# 14	0.12631	org localhost oct com received slashnull jmason dogma sep taint http ist jalapeno esmtp rssfeeds spamassassin date example yyyy tue
#
# [beta: 0.01896]
# <250> LL/token: -6.9336
# [beta: 0.019]
# <260> LL/token: -6.92842
# [beta: 0.01908]
# <270> LL/token: -6.92376
# [beta: 0.0191]
# <280> LL/token: -6.92188
# [beta: 0.01915]
# <290> LL/token: -6.92001
#
# 0	0.00659	http www com net radio NUM html org weblogs com/NUM asp blogspot php blog weblog admanmail netnoir web news jeweldive
# 1	0.0255	font size NUM color face nbsp arial align center verdana style width div sans table helvetica com span serif href
# 2	0.0512	com xent fork NUM localhost list received org sep mailto admin esmtp http subject postfix request taint spamassassin net version
# 3	0.00878	bNUM dNUM aNUM cNUM eNUM fNUM commits tim NUM net comcast sep date python spambayes return spam skip message content
# 4	0.07822	com received localhost net org aug yahoo zzzz netnoteinc NUM esmtp content mail http smtp mon subject sep jul message
# 5	0.14123	NUM one people get email mail time make would com like money free send work business order received report list
# 6	0.01786	http www href nbsp lockergnome com html NUM table border class target blank title type web value name text input
# 7	0.0129	NUM width http height src img gif font www border cnet href com/b bgcolor table online clickthru com/click size zdnet
# 8	0.01341	NUM com exmh org redhat users spamassassin taint workers listman received example list localhost mxNUM sep aug esmtp int subject
# 9	0.01741	NUM net freshrpms rpm list zzzlist egwn localhost received http esmtp lists mailto admin subject org oct net/mailman/listinfo/rpm request version
# 10	0.01507	NUMd NUM NUMdNUM width http height NUMe font size www table src img option value border align gif bgcolor name
# 11	0.00873	NUM net pro jul ssz cypherpunks minder cpunks einstein zoo petting received sightings locust waste cdt envelope NUMxdeadbeef com list
# 12	0.0509	NUM net sourceforge linux localhost received ilug org list spamassassin example aug users com esmtp talk razor admin lists lugh
# 13	0.05943	said world NUM company states security new government united also one technology would companies people years first xml president information
# 14	0.06998	org localhost oct com received dogma slashnull jmason sep taint http jalapeno rssfeeds ist esmtp date spamassassin example yyyy tue
#
# [beta: 0.01913]
# <300> LL/token: -6.91681
# [beta: 0.01917]
# <310> LL/token: -6.91555
# [beta: 0.01918]
# <320> LL/token: -6.91481
# [beta: 0.01919]
# <330> LL/token: -6.91316
# [beta: 0.01919]
# <340> LL/token: -6.91174
#
# 0	0.00581	http www com net NUM radio html org weblogs com/NUM blogspot php asp blog weblog admanmail netnoir web news jeweldive
# 1	0.0231	font size NUM color face nbsp arial align center verdana style div width helvetica table serif span com sans href
# 2	0.04618	com xent fork NUM localhost list received org sep mailto admin esmtp subject http postfix request taint spamassassin net aug
# 3	0.00825	bNUM dNUM aNUM cNUM eNUM fNUM commits tim comcast NUM net sep date python spambayes message spam return skip content
# 4	0.06794	com received localhost net org aug yahoo zzzz NUM netnoteinc content esmtp mail http smtp subject mon sep jul message
# 5	0.12394	NUM one get people com email time mail make would like money free send work order want also received address
# 6	0.0141	http www href nbsp lockergnome com NUM html table border font class target blank title type size value name web
# 7	0.01154	NUM width http height src img gif font www cnet border href com/b bgcolor online table clickthru com/click size zdnet
# 8	0.01183	NUM com exmh org redhat users spamassassin taint workers listman received example list localhost mxNUM sep aug esmtp int subject
# 9	0.01504	NUM net freshrpms rpm list zzzlist egwn localhost received http esmtp lists mailto admin subject org oct com net/mailman/listinfo/rpm version
# 10	0.01436	NUMd NUM NUMdNUM width http height font NUMe size www table src img option value border align gif bgcolor type
# 11	0.00786	NUM net pro ssz jul cypherpunks minder cpunks einstein zoo petting received sightings locust envelope waste cdt NUMxdeadbeef lists esmtp
# 12	0.04481	NUM net sourceforge linux localhost received ilug org list spamassassin example aug users com esmtp talk razor admin lists lugh
# 13	0.05079	said world company states security NUM new government also united technology one people would companies first xml years president information
# 14	0.06172	org localhost oct com received dogma slashnull jmason sep taint http jalapeno rssfeeds ist esmtp date spamassassin example yyyy tue
#
# [beta: 0.0192]
# <350> LL/token: -6.91136
# [beta: 0.01924]
# <360> LL/token: -6.90995
# [beta: 0.01922]
# <370> LL/token: -6.90864
# [beta: 0.01924]
# <380> LL/token: -6.90698
# [beta: 0.01924]
# <390> LL/token: -6.9051
#
# 0	0.00532	http www com net NUM radio html weblogs org com/NUM blogspot php asp blog weblog netnoir admanmail web news jeweldive
# 1	0.02167	font size NUM color face nbsp arial align center verdana style div width serif sans com table helvetica span href
# 2	0.04504	com xent fork NUM localhost list received org sep mailto admin esmtp http subject postfix request taint spamassassin net version
# 3	0.00777	bNUM dNUM aNUM cNUM eNUM fNUM commits tim NUM net comcast sep python spambayes date return message skip txt content
# 4	0.06485	com received localhost net org yahoo aug zzzz NUM netnoteinc esmtp content mail http smtp subject mon sep jul message
# 5	0.11762	NUM one get people email time com make mail would like money free work new send received order internet list
# 6	0.01184	http www href nbsp lockergnome com NUM html font table border class target size blank title width type color name
# 7	0.01083	NUM width http height src img gif font www cnet border com/b href bgcolor online table clickthru com/click size zdnet
# 8	0.01123	NUM com exmh org redhat users taint spamassassin workers listman received example list localhost mxNUM sep aug esmtp int subject
# 9	0.0146	NUM net freshrpms rpm list zzzlist egwn localhost received http esmtp lists mailto admin subject org oct net/mailman/listinfo/rpm com version
# 10	0.01416	NUMd NUM NUMdNUM width http height font size NUMe www table src img option value border align gif bgcolor type
# 11	0.00749	NUM net pro jul ssz cypherpunks minder cpunks einstein zoo petting received sightings locust waste envelope cdt NUMxdeadbeef esmtp lists
# 12	0.04262	NUM net sourceforge linux localhost received ilug list org spamassassin example aug users com esmtp talk razor admin lists lugh
# 13	0.04701	said world NUM company states security government new also united one technology people would companies years first xml president news
# 14	0.05891	org localhost oct com received slashnull dogma jmason sep taint http rssfeeds jalapeno ist esmtp date spamassassin example yyyy tue
# [beta: 0.01923]
# <400> LL/token: -6.9048
# [beta: 0.01926]
# <410> LL/token: -6.90353
# [beta: 0.01926]
# <420> LL/token: -6.90361
# [beta: 0.01927]
# <430> LL/token: -6.9028
# [beta: 0.01926]
# <440> LL/token: -6.90372
#
# 0	0.0052	http www com net radio NUM html weblogs org com/NUM blogspot php asp blog weblog netnoir admanmail web news jeweldive
# 1	0.02138	font size NUM color face nbsp arial align verdana center style div width serif sans com table span helvetica href
# 2	0.04471	com xent fork NUM localhost list received org sep mailto admin esmtp http subject postfix request taint spamassassin net version
# 3	0.008	bNUM dNUM aNUM cNUM eNUM fNUM commits tim net NUM comcast sep python date spambayes return message spam content subject
# 4	0.06409	com received localhost net org yahoo aug zzzz NUM netnoteinc esmtp content mail http smtp subject mon sep jul message
# 5	0.11499	NUM one get people email time make mail would com like money free list send order work internet address also
# 6	0.01	http www href nbsp lockergnome com NUM html font table border class size target blank title width type color name
# 7	0.01034	NUM width http height src img gif font www cnet border com/b href bgcolor online table clickthru com/click size zdnet
# 8	0.01154	NUM com exmh org redhat users taint spamassassin workers listman received example list localhost mxNUM sep aug esmtp int https
# 9	0.01385	NUM net freshrpms rpm list zzzlist egwn localhost received http esmtp lists mailto admin subject org oct com net/mailman/listinfo/rpm version
# 10	0.01382	NUMd NUM NUMdNUM width http height font size NUMe www table src img option value border align gif bgcolor name
# 11	0.00719	NUM net pro jul ssz cypherpunks minder cpunks einstein zoo petting sightings received locust waste cdt envelope NUMxdeadbeef lists esmtp
# 12	0.04263	NUM net sourceforge linux localhost received ilug org list spamassassin example aug users com esmtp talk razor admin lists lugh
# 13	0.04509	said world NUM company states new government also security one united technology people would companies years first xml president law
# 14	0.05867	org localhost oct com received dogma slashnull jmason sep taint http rssfeeds jalapeno ist esmtp date spamassassin example yyyy tue
#
# [beta: 0.01926]
# <450> LL/token: -6.90272
# [beta: 0.01926]
# <460> LL/token: -6.903
# [beta: 0.01926]
# <470> LL/token: -6.90204
# [beta: 0.01927]
# <480> LL/token: -6.90257
# [beta: 0.01926]
# <490> LL/token: -6.90208
#
# 0	0.00507	http www com net NUM radio html org weblogs com/NUM blogspot php asp blog weblog web admanmail netnoir news jeweldive
# 1	0.02095	font size NUM color face nbsp arial align center verdana style div width serif com sans span helvetica table href
# 2	0.04391	com xent fork NUM localhost list received org sep mailto admin esmtp http subject postfix request taint spamassassin net version
# 3	0.00771	bNUM dNUM aNUM cNUM eNUM fNUM tim NUM comcast sep net date python spambayes return message skip spam content NUMt
# 4	0.06431	com received localhost net org yahoo aug zzzz NUM netnoteinc esmtp content mail http smtp subject mon sep jul message
# 5	0.1134	NUM one people get email time would make mail com like money send free list work order new software information
# 6	0.0095	http www href nbsp lockergnome com NUM html font table border class size target blank title width type color value
# 7	0.01025	NUM width http height src img gif font www cnet border com/b href bgcolor online table clickthru com/click size zdnet
# 8	0.01126	NUM com exmh org redhat users spamassassin taint workers listman received example list localhost mxNUM sep aug esmtp int https
# 9	0.01401	NUM net freshrpms rpm list zzzlist egwn localhost received http esmtp lists mailto admin subject org oct com net/mailman/listinfo/rpm version
# 10	0.01369	NUMd NUM NUMdNUM width http height font size NUMe www table src img option align value border gif bgcolor type
# 11	0.00739	NUM net pro jul ssz cypherpunks minder cpunks einstein zoo petting sightings received locust waste envelope cdt NUMxdeadbeef lists com
# 12	0.04216	NUM net sourceforge linux localhost received ilug org list spamassassin example aug users com esmtp talk razor admin lists lugh
# 13	0.04469	said world NUM company states one government new security united also would technology people companies years first xml president could
# 14	0.05826	org localhost oct com received slashnull dogma jmason sep taint http rssfeeds jalapeno ist esmtp spamassassin date example yyyy tue
#
# [beta: 0.01925]
# <500> LL/token: -6.90158
# [beta: 0.01925]
# <510> LL/token: -6.90064
# [beta: 0.01925]
# <520> LL/token: -6.90127
# [beta: 0.01925]
# <530> LL/token: -6.90091
# [beta: 0.01928]
# <540> LL/token: -6.90128
#
# 0	0.0048	http www com net radio NUM html weblogs org com/NUM blogspot php asp blog weblog admanmail netnoir web news jeweldive
# 1	0.0207	font size NUM color face nbsp arial align center verdana style div width serif sans com span table helvetica href
# 2	0.04442	com xent fork NUM localhost list received org sep mailto admin esmtp subject http postfix request taint spamassassin net version
# 3	0.00736	bNUM dNUM aNUM cNUM eNUM fNUM tim comcast sep net date python NUM spambayes return content spam skip message NUMt
# 4	0.06324	com received localhost net yahoo aug org zzzz NUM netnoteinc esmtp content mail http smtp mon subject sep jul message
# 5	0.11161	NUM one get people email mail time make would com like money list free send also work information order software
# 6	0.0086	http www href nbsp lockergnome com NUM html font table border class size target blank title width type color value
# 7	0.01016	NUM width http height src img gif font www cnet border href com/b bgcolor online table clickthru com/click size zdnet
# 8	0.01081	NUM com exmh org redhat users spamassassin taint workers listman received example list localhost mxNUM sep aug esmtp int https
# 9	0.0135	NUM net freshrpms rpm list zzzlist egwn localhost received http esmtp lists mailto admin subject org oct net/mailman/listinfo/rpm com version
# 10	0.01379	NUMd NUM NUMdNUM width http height font size NUMe www table src img option align value border gif bgcolor name
# 11	0.00679	NUM net pro ssz jul cypherpunks minder cpunks einstein zoo petting received sightings locust waste cdt envelope NUMxdeadbeef com lists
# 12	0.04161	NUM net sourceforge linux localhost received ilug org list spamassassin example aug users com esmtp talk razor admin lists lugh
# 13	0.0442	said world company states NUM one new government also security united technology people would companies years first business president xml
# 14	0.0573	org localhost oct com received slashnull dogma jmason sep taint http rssfeeds jalapeno ist esmtp spamassassin date example yyyy tue
#
# [beta: 0.01928]
# <550> LL/token: -6.90089
# [beta: 0.0193]
# <560> LL/token: -6.90083
# [beta: 0.0193]
# <570> LL/token: -6.90062
# [beta: 0.01929]
# <580> LL/token: -6.90013
# [beta: 0.01929]
# <590> LL/token: -6.89993
#
# 0	0.00484	http www com net NUM radio html weblogs org com/NUM blogspot php asp blog weblog admanmail netnoir web news jeweldive
# 1	0.02105	font size NUM color face nbsp arial align center verdana style div width serif com sans span helvetica table href
# 2	0.04305	com xent fork NUM localhost list received org sep mailto admin esmtp http subject postfix request taint spamassassin net version
# 3	0.00711	bNUM dNUM aNUM cNUM eNUM fNUM tim NUM net comcast sep python date spambayes return message content skip com txt
# 4	0.06226	com received localhost net yahoo org aug zzzz NUM netnoteinc esmtp content mail http smtp mon subject sep jul message
# 5	0.10951	NUM one people get email time make mail would com like money list send free work information software also order
# 6	0.00866	http www href nbsp lockergnome com NUM html font table border class size target blank title width type color name
# 7	0.01009	NUM width http src height img gif font www cnet border com/b href bgcolor online table clickthru com/click size zdnet
# 8	0.01038	NUM com exmh org redhat users taint spamassassin workers listman received example list localhost mxNUM sep aug esmtp int mailto
# 9	0.01358	NUM net freshrpms rpm list zzzlist egwn localhost received http esmtp lists mailto admin subject org oct net/mailman/listinfo/rpm com version
# 10	0.01348	NUMd NUM NUMdNUM width http height font size NUMe www table img src option border value align gif bgcolor name
# 11	0.00683	NUM net pro jul ssz cypherpunks minder cpunks einstein zoo petting received sightings locust waste envelope cdt com NUMxdeadbeef lists
# 12	0.04102	NUM net sourceforge linux localhost received ilug org list spamassassin example aug users com esmtp talk razor admin lists lugh
# 13	0.04318	said world NUM company states one new also government united security people technology would companies first years xml news president
# 14	0.05649	org localhost oct com received slashnull dogma jmason sep taint http rssfeeds jalapeno ist esmtp spamassassin date example yyyy tue
# [beta: 0.0193]
# <600> LL/token: -6.89929
# [beta: 0.01931]
# <610> LL/token: -6.89933
# [beta: 0.01931]
# <620> LL/token: -6.89968
# [beta: 0.0193]
# <630> LL/token: -6.89971
# [beta: 0.01931]
# <640> LL/token: -6.89986
#
# 0	0.00491	http www com net radio NUM html weblogs org com/NUM blogspot php asp blog weblog admanmail netnoir web news jeweldive
# 1	0.02061	font size NUM color face nbsp arial align center verdana style div width serif sans span com table helvetica href
# 2	0.04336	com xent fork NUM localhost list received org sep mailto admin esmtp subject http postfix request taint spamassassin net version
# 3	0.00721	bNUM dNUM aNUM cNUM eNUM fNUM tim sep comcast net NUM python date spambayes return message skip content org txt
# 4	0.06185	com received localhost net yahoo org aug NUM zzzz netnoteinc content esmtp mail http smtp mon subject sep jul message
# 5	0.10823	NUM one get people email time com mail make would like money list software send work also free new internet
# 6	0.00854	http www href nbsp lockergnome com NUM html font table border class size target blank title width type color input
# 7	0.00985	NUM width http height src img gif font www cnet border com/b href bgcolor online table clickthru com/click size zdnet
# 8	0.01061	NUM com exmh org redhat users spamassassin taint workers listman received example list localhost mxNUM sep aug esmtp int https
# 9	0.01361	NUM net freshrpms rpm list zzzlist egwn localhost received http esmtp lists mailto admin subject org oct com net/mailman/listinfo/rpm request
# 10	0.01335	NUMd NUM NUMdNUM width http height font size NUMe www table img src option value align border gif bgcolor com
# 11	0.00683	NUM net pro ssz jul cypherpunks minder cpunks einstein zoo petting sightings received locust waste cdt envelope NUMxdeadbeef com lists
# 12	0.04033	NUM net sourceforge linux received localhost ilug org list spamassassin example aug users com esmtp talk razor admin lists lugh
# 13	0.04284	said world one company NUM states new government united also security people would technology companies first years xml president business
# 14	0.05583	org localhost oct com received dogma slashnull jmason sep taint http rssfeeds jalapeno ist esmtp spamassassin date example yyyy tue
#
# [beta: 0.01931]
# <650> LL/token: -6.89956
# [beta: 0.01932]
# <660> LL/token: -6.89983
# [beta: 0.01931]
# <670> LL/token: -6.89992
# [beta: 0.01933]
# <680> LL/token: -6.89974
# [beta: 0.01932]
# <690> LL/token: -6.8995
#
# 0	0.00502	http www com net NUM radio html weblogs org com/NUM blogspot php asp blog weblog netnoir admanmail web news jeweldive
# 1	0.02051	font size NUM color face nbsp arial align verdana center style div width serif sans table helvetica com span href
# 2	0.04338	com xent fork NUM localhost list received org sep mailto admin esmtp subject http postfix request taint spamassassin net version
# 3	0.00696	bNUM dNUM aNUM cNUM eNUM fNUM tim NUM sep comcast net date python spambayes content spam return message com skip
# 4	0.06168	com received localhost net yahoo org aug zzzz NUM netnoteinc esmtp content mail http smtp mon subject sep jul message
# 5	0.10783	NUM one get people email com make time mail like would money list software send work also internet information new
# 6	0.00836	http www href nbsp lockergnome com NUM html font table border class size target blank title type width color value
# 7	0.00991	NUM width http height src img gif font www cnet border com/b href bgcolor online table clickthru com/click size zdnet
# 8	0.01071	NUM com exmh org redhat users spamassassin taint workers listman received example list localhost mxNUM sep aug esmtp int https
# 9	0.01364	NUM net freshrpms rpm list zzzlist egwn localhost received http esmtp lists mailto admin subject org oct com net/mailman/listinfo/rpm version
# 10	0.01336	NUMd NUM NUMdNUM width http height font size NUMe www table img src option value align border gif bgcolor type
# 11	0.00667	NUM net pro ssz jul cypherpunks minder cpunks einstein zoo petting sightings received locust waste envelope cdt NUMxdeadbeef lists list
# 12	0.04005	NUM net sourceforge linux localhost received ilug org list spamassassin example aug users com esmtp talk razor admin lists lugh
# 13	0.04349	said world NUM company one states government also new united would people security technology companies years first could xml president
# 14	0.05616	org localhost oct com received slashnull dogma jmason sep taint http jalapeno rssfeeds ist esmtp spamassassin date example yyyy tue
#
# [beta: 0.01931]
# <700> LL/token: -6.90027
# [beta: 0.01931]
# <710> LL/token: -6.8998
# [beta: 0.0193]
# <720> LL/token: -6.90005
# [beta: 0.01929]
# <730> LL/token: -6.9001
# [beta: 0.0193]
# <740> LL/token: -6.89996
#
# 0	0.00484	http www com net radio NUM html weblogs org com/NUM blogspot php asp blog weblog admanmail web netnoir news jeweldive
# 1	0.02079	font size NUM color face nbsp arial align center verdana style div serif width sans com span helvetica table href
# 2	0.04312	com xent fork NUM localhost list received org sep mailto admin esmtp subject http postfix request taint spamassassin net version
# 3	0.00706	bNUM dNUM aNUM cNUM eNUM fNUM tim net sep comcast NUM date python spambayes return message spam content skip txt
# 4	0.06241	com received localhost net yahoo aug org zzzz NUM netnoteinc esmtp content mail http smtp subject mon sep message jul
# 5	0.109	NUM one people get email time make com would mail like money list also send work software new free information
# 6	0.00819	http www href nbsp lockergnome com html NUM font table border class size target blank title width type color value
# 7	0.01015	NUM width http height src img gif font www cnet border com/b href bgcolor online table clickthru com/click size zdnet
# 8	0.01034	NUM com exmh org redhat users spamassassin taint workers listman received example list localhost mxNUM sep aug esmtp int https
# 9	0.01351	NUM net freshrpms rpm list zzzlist egwn localhost received http esmtp lists mailto admin subject org oct com net/mailman/listinfo/rpm version
# 10	0.01323	NUMd NUM NUMdNUM width http height font size NUMe www table src img option value align border gif bgcolor name
# 11	0.0069	NUM net pro ssz jul cypherpunks minder cpunks einstein zoo petting received sightings locust waste envelope cdt NUMxdeadbeef com esmtp
# 12	0.03996	NUM net sourceforge linux localhost received ilug org list spamassassin example aug users com esmtp talk razor admin lists lugh
# 13	0.0428	said world NUM company states new government one united also security people technology would companies years first president xml could
# 14	0.05584	org localhost oct com received slashnull dogma jmason sep taint http rssfeeds ist jalapeno esmtp spamassassin date example yyyy tue
#
# [beta: 0.01932]
# <750> LL/token: -6.90039
# [beta: 0.01932]
# <760> LL/token: -6.89998
# [beta: 0.01933]
# <770> LL/token: -6.89949
# [beta: 0.01934]
# <780> LL/token: -6.90036
# [beta: 0.01932]
# <790> LL/token: -6.89943
#
# 0	0.00467	http www com net radio NUM html weblogs org com/NUM blogspot php asp blog weblog admanmail netnoir web news jeweldive
# 1	0.02046	font size NUM color face nbsp arial align center verdana style div width serif sans span com table helvetica href
# 2	0.04318	com xent fork NUM localhost list received org sep mailto admin esmtp http subject postfix request taint spamassassin net version
# 3	0.00683	bNUM dNUM aNUM cNUM eNUM fNUM tim NUM net comcast sep date python spambayes content return skip message txt NUMt
# 4	0.06238	com received localhost net org aug yahoo zzzz NUM netnoteinc esmtp content mail http smtp mon subject sep jul message
# 5	0.10836	NUM one get people email com time make mail would like money list free net send work new also software
# 6	0.00787	http www href nbsp lockergnome com NUM html font table border class size target blank title width type color name
# 7	0.00993	NUM width http height src img gif font www cnet border com/b href bgcolor table online clickthru com/click size zdnet
# 8	0.01067	NUM com exmh org redhat users spamassassin taint workers listman received example list localhost mxNUM sep aug esmtp int https
# 9	0.01358	NUM net freshrpms rpm list zzzlist egwn localhost received http esmtp lists mailto admin subject org oct net/mailman/listinfo/rpm request com
# 10	0.01344	NUMd NUM NUMdNUM width http height font size NUMe www table src img option value align border gif bgcolor name
# 11	0.00683	NUM net pro ssz jul cypherpunks minder cpunks einstein zoo petting sightings received locust waste cdt envelope NUMxdeadbeef lists esmtp
# 12	0.03998	NUM net sourceforge linux localhost received ilug org list spamassassin example aug users com esmtp talk razor admin lists lugh
# 13	0.04275	said world NUM company states one government new united also security would people technology companies years first time president xml
# 14	0.05555	org localhost oct com received dogma slashnull jmason sep taint http rssfeeds jalapeno ist esmtp date spamassassin example yyyy tue
# [beta: 0.01932]
# <800> LL/token: -6.90007
# [beta: 0.01931]
# <810> LL/token: -6.90061
# [beta: 0.01931]
# <820> LL/token: -6.89947
# [beta: 0.0193]
# <830> LL/token: -6.89946
# [beta: 0.0193]
# <840> LL/token: -6.90021
#
# 0	0.00475	http www com net NUM radio html weblogs org com/NUM blogspot php asp blog weblog admanmail netnoir web news jeweldive
# 1	0.02049	font size NUM color face nbsp arial align center verdana style div serif sans width span com helvetica table href
# 2	0.04346	com xent fork NUM localhost list received org sep mailto admin esmtp subject http postfix request taint spamassassin net version
# 3	0.00722	bNUM dNUM aNUM cNUM eNUM fNUM tim comcast sep NUM net date python spambayes content message skip spam txt return
# 4	0.06144	com received localhost net yahoo org aug zzzz NUM netnoteinc content esmtp mail http smtp mon subject sep jul message
# 5	0.10872	NUM one people get email com time mail make would like money software list new send work also free information
# 6	0.00819	http www href nbsp lockergnome com NUM html font table border class size target blank title width type color value
# 7	0.00985	NUM width http height src img gif font www cnet border com/b href bgcolor table online clickthru com/click size zdnet
# 8	0.0104	NUM com exmh org redhat users spamassassin taint workers listman received example list localhost mxNUM sep aug esmtp int mailto
# 9	0.01387	NUM net freshrpms rpm list zzzlist egwn localhost received http esmtp lists mailto admin subject org oct net/mailman/listinfo/rpm com request
# 10	0.01358	NUMd NUM NUMdNUM width http height font size NUMe www table src img option value border align gif bgcolor name
# 11	0.00675	NUM net pro ssz jul cypherpunks minder cpunks einstein zoo petting received sightings locust waste cdt envelope NUMxdeadbeef com list
# 12	0.04055	NUM net sourceforge linux localhost received ilug org spamassassin list example aug users com esmtp talk razor admin lists lugh
# 13	0.04328	said world NUM company states one new government also united security people would technology companies years first xml president american
# 14	0.05625	org localhost oct com received slashnull dogma jmason sep taint http rssfeeds jalapeno ist esmtp spamassassin date example yyyy tue
#
# [beta: 0.01932]
# <850> LL/token: -6.89978
# [beta: 0.01932]
# <860> LL/token: -6.89932
# [beta: 0.01931]
# <870> LL/token: -6.89931
# [beta: 0.0193]
# <880> LL/token: -6.89932
# [beta: 0.01932]
# <890> LL/token: -6.89972
#
# 0	0.00477	http www com net radio NUM html weblogs org com/NUM blogspot php asp blog weblog admanmail netnoir web news jeweldive
# 1	0.02062	font size NUM color face nbsp arial align center verdana style div width serif table com sans span helvetica href
# 2	0.04327	com xent fork NUM localhost list received org sep mailto admin esmtp subject http postfix request taint spamassassin net version
# 3	0.00686	bNUM dNUM aNUM cNUM eNUM fNUM tim net sep comcast NUM python date spambayes content return skip message com txt
# 4	0.06227	com received localhost net org yahoo aug zzzz NUM netnoteinc esmtp content mail http smtp mon subject sep message jul
# 5	0.10716	NUM one get people email mail com time make would like money software free send list new also use work
# 6	0.00817	http www href nbsp lockergnome com NUM html font table border class target size blank title type width color value
# 7	0.00997	NUM width http height src img gif font www cnet border com/b href bgcolor online table clickthru com/click size zdnet
# 8	0.01035	NUM com exmh org redhat users spamassassin taint workers listman received example list localhost mxNUM sep aug esmtp int mailto
# 9	0.01371	NUM net freshrpms rpm list zzzlist egwn localhost received http esmtp lists mailto admin subject org oct com net/mailman/listinfo/rpm request
# 10	0.01341	NUMd NUM NUMdNUM width http height font size NUMe www table src img option value border align gif bgcolor com
# 11	0.00671	NUM net pro jul ssz cypherpunks minder cpunks einstein zoo petting received sightings locust waste com cdt envelope NUMxdeadbeef esmtp
# 12	0.04016	NUM net sourceforge linux localhost received ilug org list spamassassin example aug users com esmtp talk razor admin lists lugh
# 13	0.04318	said world NUM company one states government new also united security people would technology companies years first president xml news
# 14	0.05544	org localhost oct com received slashnull dogma jmason sep taint http jalapeno rssfeeds ist esmtp spamassassin date example yyyy tue
#
# [beta: 0.01932]
# <900> LL/token: -6.89951
# [beta: 0.01933]
# <910> LL/token: -6.90001
# [beta: 0.01931]
# <920> LL/token: -6.89992
# [beta: 0.0193]
# <930> LL/token: -6.90021
# [beta: 0.01932]
# <940> LL/token: -6.89979
#
# 0	0.00478	http www com net NUM radio html weblogs org com/NUM blogspot php asp blog weblog netnoir admanmail web news jeweldive
# 1	0.02092	font size NUM color face nbsp arial align center verdana style div width serif com sans span table helvetica href
# 2	0.0436	com xent fork NUM localhost list received org sep mailto admin esmtp subject http postfix request taint spamassassin net version
# 3	0.00729	bNUM dNUM aNUM cNUM eNUM fNUM tim comcast NUM sep net date python spambayes spam content return message skip txt
# 4	0.06195	com received localhost net org yahoo aug zzzz NUM netnoteinc esmtp content mail http mon smtp subject sep jul message
# 5	0.1068	NUM one get people com email make time mail would like money new software list send also work net free
# 6	0.00772	http www href nbsp lockergnome com NUM html font table border class target size blank title type width color value
# 7	0.01011	NUM width http height src img gif font www cnet border com/b href bgcolor online table clickthru com/click size zdnet
# 8	0.01083	NUM com exmh org redhat users spamassassin taint workers listman received example list localhost mxNUM sep aug esmtp int subject
# 9	0.01378	NUM net freshrpms rpm list zzzlist egwn localhost received http esmtp lists mailto admin subject org oct com net/mailman/listinfo/rpm request
# 10	0.01332	NUMd NUM NUMdNUM width http height font size NUMe www table src img option align value border gif bgcolor type
# 11	0.00637	NUM net pro ssz jul cypherpunks minder cpunks einstein zoo petting sightings received locust waste cdt envelope NUMxdeadbeef com esmtp
# 12	0.04074	NUM net sourceforge linux localhost received ilug org list spamassassin example aug users com esmtp talk razor admin lists lugh
# 13	0.04237	said world NUM company states one new government united also people security technology would companies years first president xml american
# 14	0.05633	org localhost oct com received dogma slashnull jmason sep taint http rssfeeds jalapeno ist esmtp spamassassin date example yyyy tue
#
# [beta: 0.01932]
# <950> LL/token: -6.89952
# [beta: 0.01932]
# <960> LL/token: -6.89986
# [beta: 0.01931]
# <970> LL/token: -6.89932
# [beta: 0.01931]
# <980> LL/token: -6.89992
# [beta: 0.0193]
# <990> LL/token: -6.90002
#
# 0	0.00455	http www com net radio NUM html weblogs org com/NUM blogspot php asp blog weblog netnoir admanmail web news jeweldive
# 1	0.02087	font size NUM color face nbsp arial align center verdana style div width serif sans com span table helvetica href
# 2	0.04332	com xent fork NUM localhost list received org sep mailto admin esmtp subject http postfix request taint spamassassin net version
# 3	0.00704	bNUM dNUM aNUM cNUM eNUM fNUM tim NUM net comcast sep date python spambayes return spam content skip com txt
# 4	0.06158	com received localhost net yahoo org aug zzzz NUM netnoteinc esmtp content mail http smtp subject mon sep jul message
# 5	0.109	NUM one get people com email make time mail would like money software also work send list information free internet
# 6	0.00753	http www href nbsp lockergnome com NUM html font table border class size target blank title width type color value
# 7	0.01021	NUM width http height src img gif font www cnet border com/b href bgcolor online table clickthru com/click size zdnet
# 8	0.01078	NUM com exmh org redhat users spamassassin taint workers listman received example list localhost mxNUM sep aug esmtp int mailto
# 9	0.0136	NUM net freshrpms rpm list zzzlist egwn localhost received http esmtp lists mailto admin subject org oct com net/mailman/listinfo/rpm request
# 10	0.01325	NUMd NUM NUMdNUM width http height font size NUMe www table src img option value border align gif bgcolor name
# 11	0.00686	NUM net pro ssz jul cypherpunks minder cpunks einstein zoo petting sightings received locust waste envelope cdt NUMxdeadbeef lists com
# 12	0.04048	NUM net sourceforge linux received localhost ilug org list spamassassin example aug users com esmtp talk razor admin lists lugh
# 13	0.04254	said world company NUM states one new government united also security would people technology years companies first president xml time
# 14	0.05527	org localhost oct com received slashnull dogma jmason sep taint http rssfeeds jalapeno ist esmtp spamassassin date example yyyy tue
# [beta: 0.01932]
# <1000> LL/token: -6.89976
#
# Total time: 5 minutes 55 seconds
# Complete

# %%
# Organizing the results into a dictionary
topic_word_probability_dict = lmw.load_topic_word_distributions(output_directory_path + '/mallet.word_weights.' + str(num_topics))
len(topic_word_probability_dict)

for _topic, _word_probability_dict in topic_word_probability_dict.items():
    print('Topic', _topic)
    for _word, _probability in sorted(_word_probability_dict.items(), key=lambda x: x[1], reverse=True)[:15]:
        print(round(_probability, 4), '\t', _word)
    print()
# Out:
# Topic 0
# 0.1053 	 http
# 0.0577 	 www
# 0.0469 	 com
# 0.013 	 net
# 0.011 	 NUM
# 0.0107 	 radio
# 0.0087 	 html
# 0.0081 	 weblogs
# 0.0078 	 org
# 0.0066 	 com/NUM
# 0.0059 	 blogspot
# 0.0054 	 php
# 0.0045 	 asp
# 0.0045 	 blog
# 0.0044 	 weblog
#
# Topic 1
# 0.1325 	 font
# 0.0426 	 size
# 0.0366 	 NUM
# 0.0332 	 color
# 0.032 	 face
# 0.0265 	 nbsp
# 0.0213 	 arial
# 0.0184 	 align
# 0.0144 	 verdana
# 0.0144 	 center
# 0.0139 	 style
# 0.0123 	 div
# 0.0109 	 width
# 0.0106 	 serif
# 0.0101 	 sans
#
# Topic 2
# 0.0691 	 com
# 0.0574 	 xent
# 0.0487 	 fork
# 0.0315 	 NUM
# 0.023 	 localhost
# 0.0229 	 list
# 0.0212 	 received
# 0.0205 	 org
# 0.0151 	 sep
# 0.0148 	 mailto
# 0.0146 	 admin
# 0.014 	 esmtp
# 0.0137 	 subject
# 0.0137 	 http
# 0.0112 	 postfix
#
# Topic 3
# 0.0346 	 bNUM
# 0.0336 	 dNUM
# 0.0311 	 aNUM
# 0.0304 	 cNUM
# 0.0109 	 eNUM
# 0.0096 	 fNUM
# 0.0077 	 tim
# 0.0067 	 NUM
# 0.0066 	 net
# 0.0065 	 comcast
# 0.0065 	 sep
# 0.0056 	 date
# 0.0055 	 python
# 0.0054 	 spambayes
# 0.0039 	 content
#
# Topic 4
# 0.0704 	 com
# 0.0287 	 received
# 0.023 	 localhost
# 0.0162 	 net
# 0.0143 	 org
# 0.0142 	 yahoo
# 0.0138 	 aug
# 0.0135 	 zzzz
# 0.0127 	 NUM
# 0.0116 	 netnoteinc
# 0.0111 	 esmtp
# 0.011 	 content
# 0.0106 	 mail
# 0.0098 	 http
# 0.0082 	 smtp
#
# Topic 5
# 0.0316 	 NUM
# 0.008 	 one
# 0.0059 	 people
# 0.0059 	 get
# 0.0054 	 com
# 0.0051 	 email
# 0.0049 	 time
# 0.0048 	 make
# 0.0046 	 mail
# 0.0046 	 would
# 0.0043 	 like
# 0.0037 	 money
# 0.0033 	 also
# 0.0033 	 free
# 0.0033 	 software
#
# Topic 6
# 0.0435 	 http
# 0.0325 	 www
# 0.0302 	 href
# 0.0263 	 nbsp
# 0.0207 	 lockergnome
# 0.0166 	 com
# 0.0144 	 html
# 0.0142 	 NUM
# 0.0137 	 font
# 0.012 	 table
# 0.0109 	 border
# 0.0096 	 class
# 0.0088 	 target
# 0.0088 	 size
# 0.0083 	 blank
#
# Topic 7
# 0.088 	 NUM
# 0.0652 	 width
# 0.0562 	 http
# 0.0386 	 height
# 0.0384 	 src
# 0.0379 	 img
# 0.0361 	 gif
# 0.0315 	 font
# 0.0255 	 www
# 0.0248 	 cnet
# 0.0241 	 border
# 0.0192 	 com/b
# 0.019 	 href
# 0.0175 	 bgcolor
# 0.0175 	 online
#
# Topic 8
# 0.0982 	 NUM
# 0.0542 	 com
# 0.0477 	 exmh
# 0.0261 	 org
# 0.0248 	 redhat
# 0.0231 	 users
# 0.0214 	 spamassassin
# 0.0214 	 taint
# 0.0208 	 workers
# 0.0207 	 listman
# 0.0187 	 received
# 0.0172 	 example
# 0.0163 	 list
# 0.0152 	 localhost
# 0.0128 	 mxNUM
#
# Topic 9
# 0.0635 	 NUM
# 0.0603 	 net
# 0.0504 	 freshrpms
# 0.0479 	 rpm
# 0.042 	 list
# 0.0289 	 zzzlist
# 0.0192 	 egwn
# 0.0167 	 localhost
# 0.0148 	 received
# 0.0127 	 http
# 0.011 	 esmtp
# 0.0102 	 lists
# 0.0099 	 mailto
# 0.0098 	 admin
# 0.0098 	 subject
#
# Topic 10
# 0.2299 	 NUMd
# 0.0835 	 NUM
# 0.037 	 NUMdNUM
# 0.0303 	 width
# 0.0185 	 http
# 0.0154 	 height
# 0.0136 	 font
# 0.0124 	 size
# 0.0121 	 NUMe
# 0.012 	 www
# 0.0111 	 table
# 0.0105 	 src
# 0.0103 	 img
# 0.0098 	 option
# 0.0097 	 value
#
# Topic 11
# 0.2483 	 NUM
# 0.0324 	 net
# 0.0135 	 pro
# 0.0114 	 ssz
# 0.0112 	 jul
# 0.0108 	 cypherpunks
# 0.0102 	 minder
# 0.0096 	 cpunks
# 0.0088 	 einstein
# 0.0071 	 zoo
# 0.0071 	 petting
# 0.0061 	 received
# 0.0059 	 sightings
# 0.0044 	 locust
# 0.0043 	 waste
#
# Topic 12
# 0.0565 	 NUM
# 0.0403 	 net
# 0.0342 	 sourceforge
# 0.0249 	 linux
# 0.0192 	 localhost
# 0.019 	 received
# 0.0173 	 ilug
# 0.0169 	 org
# 0.0167 	 list
# 0.0165 	 spamassassin
# 0.0154 	 example
# 0.0152 	 aug
# 0.015 	 users
# 0.0133 	 com
# 0.0128 	 esmtp
#
# Topic 13
# 0.0049 	 said
# 0.0044 	 world
# 0.0035 	 NUM
# 0.0035 	 one
# 0.0034 	 states
# 0.0034 	 company
# 0.0032 	 government
# 0.0031 	 united
# 0.0031 	 new
# 0.003 	 also
# 0.0029 	 people
# 0.0028 	 security
# 0.0028 	 would
# 0.0028 	 technology
# 0.0024 	 companies
#
# Topic 14
# 0.0708 	 org
# 0.0468 	 localhost
# 0.0383 	 oct
# 0.0308 	 com
# 0.0257 	 received
# 0.0224 	 dogma
# 0.0223 	 slashnull
# 0.0219 	 jmason
# 0.0189 	 sep
# 0.0184 	 taint
# 0.0181 	 http
# 0.0165 	 rssfeeds
# 0.0163 	 jalapeno
# 0.0162 	 ist
# 0.0159 	 esmtp

# %%
directory = combined_df['directory'].tolist()

target_labels = ["easy_ham", 
                 "easy_ham_2", 
                 "hard_ham", 
                 "spam", 
                 "spam_2"]

lmw.plot_categories_by_topics_heatmap(directory,
                                      topic_distributions,
                                      topic_keys, 
                                      output_directory_path + '/categories_by_topics.pdf',
                                      target_labels=target_labels,
                                      dim=(14,8))

# %%
print('Spam directory is related to the following topics : \n', pd.DataFrame([','.join(i) for i in topic_keys]).iloc[0,0],'\t', pd.DataFrame([','.join(i) for i in topic_keys]).iloc[3,0],'\t', pd.DataFrame([','.join(i) for i in topic_keys]).iloc[4,0])
print('\n','Spam_2 directory is related to the following topics : \n', pd.DataFrame([','.join(i) for i in topic_keys]).iloc[0,0],'\n',pd.DataFrame([','.join(i) for i in topic_keys]).iloc[5,0])
# Out:
# Spam directory is related to the following topics :
#  http,www,com,net,NUM,radio,html,weblogs,org,com/NUM,blogspot,php,asp,blog,weblog,netnoir,admanmail,web,news,jeweldive 	 bNUM,dNUM,aNUM,cNUM,eNUM,fNUM,tim,NUM,net,comcast,sep,date,python,spambayes,content,return,skip,txt,spam,delivery 	 com,received,localhost,net,org,yahoo,aug,zzzz,NUM,netnoteinc,esmtp,content,mail,http,smtp,subject,mon,sep,jul,message
#
#  Spam_2 directory is related to the following topics :
#  http,www,com,net,NUM,radio,html,weblogs,org,com/NUM,blogspot,php,asp,blog,weblog,netnoir,admanmail,web,news,jeweldive
#  NUM,one,people,get,com,email,time,make,mail,would,like,money,also,free,software,send,new,list,work,internet

# %% [markdown]
# ## Clustering

# %%
NUM_CLUSTERS = 15
km = KMeans(n_clusters=NUM_CLUSTERS, max_iter=10000, n_init=10, random_state=42).fit(tf_matrix)
km

df['kmeans_cluster'] = km.labels_

email_clusters = (df[['directory', 'kmeans_cluster']]
                  .sort_values(by=['kmeans_cluster'], 
                               ascending=False)
                  .groupby('kmeans_cluster').head(20))  # top 20 movies for each cluster
email_clusters = email_clusters.copy(deep=True)

feature_names = tf.get_feature_names()
topn_features = 15
ordered_centroids = km.cluster_centers_.argsort()[:, ::-1]

sample_silhouette_values = silhouette_samples(tf_matrix, km.labels_)

# get key features for each cluster
for cluster_num in range(NUM_CLUSTERS):

    cluster_silhouette_values = sample_silhouette_values[km.labels_ == cluster_num]

    key_features = [feature_names[index] 
                        for index in ordered_centroids[cluster_num, :topn_features]]
    print('CLUSTER #'+str(cluster_num+1), ":", cluster_silhouette_values.mean())
    print('Cluster Size', cluster_silhouette_values.shape[0])
    print('Key Features:', key_features)
    print('-'*80)
# Out:
# CLUSTER #1 : 0.24944832267230824
# Cluster Size 218
# Key Features: ['yahoo', 'yahoogroups com', 'yahoogroups', 'zzzzteana', 'yahoo com', 'grp scd', 'grp scd yahoo', 'scd', 'scd yahoo com', 'scd yahoo', 'grp', 'zzzzteana yahoogroups', 'zzzzteana yahoogroups com', 'groups', 'forteana']
# --------------------------------------------------------------------------------
# CLUSTER #2 : 0.09463603457153336
# Cluster Size 605
# Key Features: ['rssfeeds', 'oct', 'spamassassin taint org', 'spamassassin taint', 'taint org', 'taint', 'rssfeeds spamassassin taint', 'rssfeeds spamassassin', 'spamassassin', 'sep', 'tue oct', 'jmason org', 'jmason', 'path rssfeeds spamassassin', 'utf url']
# --------------------------------------------------------------------------------
# CLUSTER #3 : -0.015095537273865055
# Cluster Size 2121
# Key Features: ['net', 'perl', 'aug', 'zzzz', 'sep', 'jul', 'use perl', 'netnoteinc com', 'netnoteinc', 'font', 'mon', 'mail', 'zzzz localhost', 'perl org', 'webnote']
# --------------------------------------------------------------------------------
# CLUSTER #4 : 0.21142142557381002
# Cluster Size 474
# Key Features: ['3d', 'font', 'width 3d', 'size 3d', 'width', 'size', 'color 3d', 'td', 'color', 'face 3d', 'face', '20', '3d http', 'font face 3d', 'align']
# --------------------------------------------------------------------------------
# CLUSTER #5 : 0.35141369159442093
# Cluster Size 658
# Key Features: ['rpm', 'freshrpms', 'freshrpms net', 'zzzlist', 'rpm zzzlist', 'net', 'rpm list', 'egwn', 'list', 'egwn net', 'zzzlist freshrpms', 'zzzlist freshrpms net', 'rpm zzzlist freshrpms', 'http lists freshrpms', 'lists freshrpms']
# --------------------------------------------------------------------------------
# CLUSTER #6 : 0.17302184480598956
# Cluster Size 367
# Key Features: ['sourceforge net', 'sourceforge', 'spamassassin talk', 'talk', 'net', 'spamassassin', 'example sourceforge', 'example sourceforge net', 'lists', 'usw', 'lists sourceforge net', 'lists sourceforge', 'example', 'talk admin', 'mailto spamassassin']
# --------------------------------------------------------------------------------
# CLUSTER #7 : 0.17673802557736054
# Cluster Size 1741
# Key Features: ['fork', 'xent com', 'xent', 'fork admin xent', 'admin xent', 'admin xent com', 'fork admin', 'mailto fork', 'sep', 'http xent com', 'http xent', 'list', 'xent com subject', 'fork request xent', 'request xent']
# --------------------------------------------------------------------------------
# CLUSTER #8 : 0.2464098316002266
# Cluster Size 206
# Key Features: ['exmh users', 'exmh', 'users', 'redhat com', 'listman', 'redhat', 'mx1', 'example com', 'spamassassin taint org', 'spamassassin taint', 'taint org', 'taint', 'spamassassin', 'listman redhat com', 'listman redhat']
# --------------------------------------------------------------------------------
# CLUSTER #9 : 0.05947292054464942
# Cluster Size 676
# Key Features: ['font', 'width', 'td', 'size', 'height', 'nbsp', 'href http', 'src http', 'face', 'href', 'color', 'border', 'img', 'src', 'table']
# --------------------------------------------------------------------------------
# CLUSTER #10 : 0.26208587402740147
# Cluster Size 203
# Key Features: ['exmh', 'exmh workers', 'workers', 'redhat com', 'listman', 'redhat', 'deepeddy', 'mx1', 'spamassassin taint org', 'spamassassin taint', 'taint org', 'taint', 'vircio', 'spamassassin', 'vircio com']
# --------------------------------------------------------------------------------
# CLUSTER #11 : 0.17842591134414898
# Cluster Size 799
# Key Features: ['ilug', 'linux', 'ie', 'linux ie', 'lugh', 'ilug linux', 'tuatha org', 'tuatha', 'lugh tuatha', 'lugh tuatha org', 'admin linux', 'ilug admin', 'ilug admin linux', 'aug', 'ilug linux ie']
# --------------------------------------------------------------------------------
# CLUSTER #12 : 0.3254622837978718
# Cluster Size 295
# Key Features: ['razor', 'razor users', 'sourceforge net', 'sourceforge', 'users', 'net', 'example sourceforge', 'example sourceforge net', 'lists', 'lists sourceforge', 'lists sourceforge net', 'usw', 'example', 'users example sourceforge', 'razor users example']
# --------------------------------------------------------------------------------
# CLUSTER #13 : 0.082248157326386
# Cluster Size 623
# Key Features: ['example com', 'rssfeeds', 'oct', 'example', 'rssfeeds example com', 'rssfeeds example', 'tue oct', 'sep', 'spam', 'jmason org', 'jmason', 'path rssfeeds example', 'level url', 'spam level url', 'level url http']
# --------------------------------------------------------------------------------
# CLUSTER #14 : 0.37067939907264863
# Cluster Size 103
# Key Features: ['spamassassin devel', 'devel', 'sourceforge net', 'sourceforge', 'net', 'spamassassin', 'example sourceforge net', 'example sourceforge', 'lists', 'lists sourceforge', 'lists sourceforge net', 'mailto spamassassin devel', 'spamassassin devel admin', 'devel admin', 'spamassassin devel example']
# --------------------------------------------------------------------------------
# CLUSTER #15 : 0.06698882245980195
# Cluster Size 264
# Key Features: ['tim', 'comcast net', 'comcast', 'tim one', 'one comcast net', 'one comcast', 'tim one comcast', 'spambayes', 'skip', 'guido', 'python', 'ham', 'python org', 'subject spambayes', 'sep subject spambayes']
# --------------------------------------------------------------------------------

# %%
df.pivot_table(index='kmeans_cluster', columns='is_spam', values='directory', aggfunc='count')
# Out:
# is_spam              0       1
# kmeans_cluster
# 0                218.0     NaN
# 1                605.0     NaN
# 2                736.0  1385.0
# 3                 59.0   415.0
# 4                658.0     NaN
# 5                348.0    19.0
# 6               1691.0    50.0
# 7                206.0     NaN
# 8                254.0   422.0
# 9                203.0     NaN
# 10               691.0   108.0
# 11               295.0     NaN
# 12               623.0     NaN
# 13               103.0     NaN
# 14               264.0     NaN

# %%
scores = []

for k in range(1, 20):
    kmeans = KMeans(init="random", n_clusters=k, n_init=10, max_iter=300, random_state=42)
    kmeans.fit(tf_matrix)
    scores.append(kmeans.inertia_)

# %%
plt.style.use("fivethirtyeight")
plt.figure(figsize=(12,6))
plt.plot(range(1, 20), scores)
plt.xticks(range(1, 20))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()

# %% [markdown]
# ## Model Building

# %%
from imblearn.pipeline import Pipeline as imbpipeline
from sklearn.compose import ColumnTransformer
from sklearn.calibration import CalibratedClassifierCV
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as imbpipeline
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_selector as selector

categorical_features = ['in_reply','subj_caps','attachments']
numeric_features = ['body_lines']

X = df[categorical_features + numeric_features]
y = df['is_spam']

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.2,
                                                    stratify=y,
                                                    random_state=11)

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(missing_values=np.nan, strategy="median")),
    ('scaler', RobustScaler(with_centering=False))])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(missing_values=np.nan, strategy="most_frequent")),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

clfPipeline = Pipeline(steps = [['preprocessor', preprocessor],['classifier', MultinomialNB()]])


clfPipeline.fit(X_train, y_train)

y_pred = clfPipeline.predict(X_test)

print("Accurracy:", accuracy_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("F1", f1_score(y_test, y_pred))
# Out:
# Accurracy: 0.7856761090326029
# Recall: 0.2375
# Precision: 0.7651006711409396
# F1 0.36248012718600947

# %%
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import ConfusionMatrixDisplay

disp = RocCurveDisplay.from_estimator(clfPipeline, X_test, y_test)
disp = ConfusionMatrixDisplay.from_estimator(clfPipeline, X_test, y_test)

# %% [markdown]
# ## Revise Model with Clustering

# %%
categorical_features = ['in_reply','subj_caps','attachments','kmeans_cluster']
numeric_features = ['body_lines']

X = df[categorical_features + numeric_features]
y = df['is_spam']

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.2,
                                                    stratify=y,
                                                    random_state=11)

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(missing_values=np.nan, strategy="median")),
    ('scaler', RobustScaler(with_centering=False))])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(missing_values=np.nan, strategy="most_frequent")),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

clfPipeline = Pipeline(steps = [['preprocessor', preprocessor],['classifier', MultinomialNB()]])


clfPipeline.fit(X_train, y_train)

y_pred = clfPipeline.predict(X_test)

print("Accurracy:", accuracy_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("F1", f1_score(y_test, y_pred))
# Out:
# Accurracy: 0.8856226616782469
# Recall: 0.8979166666666667
# Precision: 0.7231543624161074
# F1 0.8011152416356878

# %%
disp = RocCurveDisplay.from_estimator(clfPipeline, X_test, y_test)
disp = ConfusionMatrixDisplay.from_estimator(clfPipeline, X_test, y_test)
